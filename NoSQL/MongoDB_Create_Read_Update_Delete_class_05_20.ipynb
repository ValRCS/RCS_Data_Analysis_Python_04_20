# %%
import pymongo
import json
import random

# %%
# if error then we run this cell to install
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\programdata\anaconda3\lib\site-packages (3.7.2)

# %%
import pymongo

# %%
pymongo.version
# Out:
# '3.7.2'

# %%
# needless to say in production, this information should not be public
user = "RCS_M22"
pw = "saule2020"
# Connect,
client = pymongo.MongoClient(f"mongodb://{user}:{pw}@ds147190.mlab.com:47190/cleanclimb",retryWrites=False)
#  Select Database,
db = client.cleanclimb # cleanclimb is the name of the database (that Mlab gave my account)
# Create New Collection(lazily)
mycollection = db[f'MyRandomColl_{random.randint(1,10000)}'] # insert your name here
#insert a new document(record),
result = mycollection.insert_one({"weather2":"stillsunny"})
# show all collections(tables)
db.list_collection_names()
# Out:
# ['MyRandomColl_93',
#  'MyRandomColl_47',
#  'MyRandomColl_39',
#  'MyRandomColl_62',
#  'system.indexes',
#  'MyRandomColl_5',
#  'moc',
#  'big',
#  'MyRandomColl_15',
#  'MyRandomColl_19',
#  'mycollname',
#  'MyRandomColl_28',
#  'MyRandomColl_60',
#  'mock',
#  'Liene1',
#  'Valdis_44',
#  'MyRandomColl_53',
#  'Ilze02',
#  'MyRandomColl_20',
#  'MyRandomColl_8235',
#  'MyRandomColl_85',
#  'small',
#  'Sana',
#  'MyRandomColl_31']

# %%
db.list_collection_names()
# Out:
# ['Arturs_M22_59',
#  'MyRandomColl_93',
#  'MyRandomColl_47',
#  'MyRandomColl_39',
#  'MyRandomColl_62',
#  'Viesturs_2001_M22',
#  'system.indexes',
#  'M_Beikerts_M22',
#  'MyRandomColl_5',
#  'moc',
#  'big',
#  'MyRandomColl_15',
#  'MyRandomColl_19',
#  'mycollname',
#  'MyRandomColl_28',
#  'MyRandomColl_60',
#  'mock',
#  'Liene1',
#  'MyRandomColl_828',
#  'Valdis_44',
#  'MyRandomColl_53',
#  'MyRandomColl_52',
#  'Ilze02',
#  'MyRandomColl_20',
#  'Zanes_M22',
#  'MyRandomColl_8235',
#  'MyRandomColl_85',
#  'small',
#  'Viesturs_7363',
#  'Sana',
#  'MyRandomColl_31',
#  'Viesturs_M22']

# %%
randomtables = [table for table in db.list_collection_names() if "MyRandomColl" in table]
randomtables
# Out:
# ['MyRandomColl_93',
#  'MyRandomColl_47',
#  'MyRandomColl_39',
#  'MyRandomColl_62',
#  'MyRandomColl_5',
#  'MyRandomColl_15',
#  'MyRandomColl_19',
#  'MyRandomColl_28',
#  'MyRandomColl_60',
#  'MyRandomColl_828',
#  'MyRandomColl_53',
#  'MyRandomColl_52',
#  'MyRandomColl_20',
#  'MyRandomColl_8235',
#  'MyRandomColl_85',
#  'MyRandomColl_31']

# %%
for table in randomtables:
    print(f"Dropping table: {table}")
    db.drop_collection(table)
db.list_collection_names()
# Out:
# Dropping table: MyRandomColl_93
# Dropping table: MyRandomColl_47
# Dropping table: MyRandomColl_39
# Dropping table: MyRandomColl_62
# Dropping table: MyRandomColl_5
# Dropping table: MyRandomColl_15
# Dropping table: MyRandomColl_19
# Dropping table: MyRandomColl_28
# Dropping table: MyRandomColl_60
# Dropping table: MyRandomColl_828
# Dropping table: MyRandomColl_53
# Dropping table: MyRandomColl_52
# Dropping table: MyRandomColl_20
# Dropping table: MyRandomColl_8235
# Dropping table: MyRandomColl_85
# Dropping table: MyRandomColl_31
# ['Arturs_M22_59',
#  'Julia M22',
#  'M_Beikerts_M22',
#  'Pavels.S',
#  'mycollname',
#  'Ilze02',
#  'Zanes_M22',
#  'Viesturs_M22',
#  'Aija O_M22',
#  'Viesturs_2001_M22',
#  'system.indexes',
#  'moc',
#  'big',
#  'mock',
#  'Liene1',
#  'Valdis_44',
#  'small',
#  'Sana']

# %%
# Create your own table with your name or initials and add M22 at the end

# %%
mycoll = db['Valdis_44']
cursor = mycoll.find({}) # similar to select * from sometable in SQL
results = [res for res in cursor]
print(results)
# Out:
# [{'_id': ObjectId('5e5a377da8571240dc3264fe'), 'weather2': 'stillsunny'}, {'_id': ObjectId('5e5a3a1ba857120a28e9b236'), 'hunger': 9000}, {'_id': ObjectId('5e5a3a21a857120a28e9b237'), 'hunger': 9000}, {'_id': ObjectId('5e5a3a57a857120a28e9b239'), 'hunger': 9000}, {'_id': ObjectId('5e5a3c62278f777756a1be66'), 'hunger': 9000}, {'_id': ObjectId('5e5a3cf77896ae1849982f39'), 'hunger': 9000}, {'_id': ObjectId('5e5a3cffa857120a28e9b23b'), 'newdata': 4444}, {'_id': ObjectId('5e5a3d627896ae1849982f3b'), 'newdataa': 444}, {'_id': ObjectId('5e5a3d8ea857120a28e9b23c'), 'somekey': 'somevalue', 'anotherkey': 4444}, {'_id': ObjectId('5e5a3d8ea857120a28e9b23d'), 'anotherkey': 334324, 'differentkey': [3, 2, 324, 32, 4234, 'Valdis']}, {'_id': ObjectId('5e5a3f6aa857120a28e9b23f'), 'hunger': 8000, 'school': 'Accenture', 'happiness': 'great'}, {'_id': ObjectId('5e5a48bfa857120a28e9b240'), 'hunger': 8050, 'school': 'Accenture', 'happiness': 'great'}, {'_id': ObjectId('5e5a48d7a857120a28e9b241'), 'hunger': 8000, 'school': 'Accenture', 'happiness': 'great'}, {'_id': ObjectId('5e5a3a56a857120a28e9b238'), 'hunger': 18050, 'happiness': 'great'}, {'_id': ObjectId('5ec7d7f979104fa50e4f529d'), 'hunger': 9000}]

# %%
type(cursor)
# Out:
# pymongo.cursor.Cursor

# %%
res2 = [res for res in cursor] # so second time the cursor is empty
res2
# Out:
# []

# %%
# dropping the table
db.drop_collection('Valdis_44')
# Out:
# {'ns': 'cleanclimb.Valdis_44',
#  'nIndexesWas': 1,
#  'ok': 1.0,
#  'operationTime': Timestamp(1590155578, 1),
#  '$clusterTime': {'clusterTime': Timestamp(1590155578, 1),
#   'signature': {'hash': b'>\xb5\t\xd0/\x89\xf3I\x83~\xb0\xee\x96\xfb#\xde\xa7o\xd4I',
#    'keyId': 6790253461440036866}}}

# %%
newcoll = db['Valdis_44']
newcoll.insert_one({"happiness":[1,2,100, "unlimited"]}) #the table is created here and values inserted or existing table is updated
cursor = newcoll.find({}) # similar to select * from sometable in SQL
results = [res for res in cursor]
print(results)
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d948a8571231401e3ef9'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d94ba8571231401e3efa'), 'happiness': [1, 2, 100, 'unlimited']}]

# %%
newcoll.insert_one({"hunger":9005,"food":["potatoes","milk","chocolate"]})
cursor = newcoll.find({}) # similar to select * from sometable in SQL
results = [res for res in cursor]
print(results)
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d948a8571231401e3ef9'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d94ba8571231401e3efa'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d96fa8571231401e3efb'), 'hunger': 9001, 'food': ['potatoes', 'milk', 'chocolate']}, {'_id': ObjectId('5ec7da49a8571231401e3efc'), 'happiness': 'Amazing'}, {'_id': ObjectId('5ec7da6ca8571231401e3efd'), 'somekey': 'somevalue', 'anotherkey': 4444}, {'_id': ObjectId('5ec7da6ca8571231401e3efe'), 'anotherkey': 334324, 'differentkey': [3, 2, 324, 32, 4234, 'Valdis']}, {'_id': ObjectId('5ec7db1ba8571231401e3eff'), 'hunger': 9005, 'food': ['potatoes', 'milk', 'chocolate']}]

# %%
cursor = newcoll.find({})
results = [res for res in cursor]
print(results)
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d948a8571231401e3ef9'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d94ba8571231401e3efa'), 'happiness': [1, 2, 100, 'unlimited']}, {'_id': ObjectId('5ec7d96fa8571231401e3efb'), 'hunger': 9001, 'food': ['potatoes', 'milk', 'chocolate']}]

# %%
list(newcoll.find({}))
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d948a8571231401e3ef9'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d94ba8571231401e3efa'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']}]

# %%
db.Valdis_44.insert_one({"happiness":"Amazing"})
list(db.Valdis_44.find({}))
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d948a8571231401e3ef9'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d94ba8571231401e3efa'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7da49a8571231401e3efc'), 'happiness': 'Amazing'}]

# %%
listofdicts = [
    {"somekey":"somevalue","anotherkey":4444},
    {"anotherkey":334324, "differentkey":[3,2,324,32,4234,"Valdis"]}
]
listofdicts
# Out:
# [{'somekey': 'somevalue', 'anotherkey': 4444},
#  {'anotherkey': 334324, 'differentkey': [3, 2, 324, 32, 4234, 'Valdis']}]

# %%
db.Valdis_44.insert_many(listofdicts)
list(db.Valdis_44.find({}))
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d948a8571231401e3ef9'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d94ba8571231401e3efa'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7da49a8571231401e3efc'), 'happiness': 'Amazing'},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efd'),
#   'somekey': 'somevalue',
#   'anotherkey': 4444},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efe'),
#   'anotherkey': 334324,
#   'differentkey': [3, 2, 324, 32, 4234, 'Valdis']}]

# %%
list(db.Valdis_44.find({"hunger":9001})) #select all documents where key hunger has value 9000
# somewhat similar to SQL SELECT * from Valdis_44 where Hunger = 9000
# Out:
# [{'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
list(db.Valdis_44.find({"hunger":{"$gt":9000}})) # find all documents where hunger is over 9000
# Out:
# [{'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7db1ba8571231401e3eff'),
#   'hunger': 9005,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
db.Valdis_44.insert_one({"hunger":9001, "school":"Accenture"})
list(db.Valdis_44.find({"hunger":{"$gt":9000}}))
# Out:
# [{'_id': ObjectId('5e5a3ae0a857120a28e9b23a'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5e5a3c65278f777756a1be67'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5e5a3cfb7896ae1849982f3a'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5e5a3e7da857120a28e9b23e'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5e5a3f6aa857120a28e9b23f'),
#   'hunger': 9001,
#   'school': 'Accenture'},
#  {'_id': ObjectId('5e5a48bfa857120a28e9b240'),
#   'hunger': 9001,
#   'school': 'Accenture'},
#  {'_id': ObjectId('5e5a48d7a857120a28e9b241'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
list(db.Valdis_44.find({"hunger":{"$exists":True}})) #find all documents with a hunger key
# Out:
# [{'_id': ObjectId('5ec7d96fa8571231401e3efb'),
#   'hunger': 9001,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7db1ba8571231401e3eff'),
#   'hunger': 9005,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
list(db.Valdis_44.find({"hunger":{"$exists":False}}))
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d948a8571231401e3ef9'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d94ba8571231401e3efa'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7da49a8571231401e3efc'), 'happiness': 'Amazing'},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efd'),
#   'somekey': 'somevalue',
#   'anotherkey': 4444},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efe'),
#   'anotherkey': 334324,
#   'differentkey': [3, 2, 324, 32, 4234, 'Valdis']}]

# %%
len(list(db.Valdis_44.find({"hunger":{"$gt":9000}})))
# Out:
# 3

# %%
# old command might not work on newer PyMongo
db.Valdis_44.count({"hunger":{"$gt":9000}})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 3

# %%
# recommended now to count documents
db.Valdis_44.count_documents({"hunger":{"$gt":9000}}) #in SQL SELECT COUNT(*) from table WHERE utt
# Out:
# 3

# %%
# https://docs.mongodb.com/manual/reference/operator/query-comparison/
list(db.Valdis_44.find({"hunger":{"$gt":9000}, "school":"Accenture"})) # so hunger >9000 AND school equal to Accenture
# Out:
# [{'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
# https://docs.mongodb.com/manual/tutorial/remove-documents/
db.Valdis_44.delete_one({"hunger":{"$gt":9000}})
db.Valdis_44.count_documents({"hunger":{"$gt":9000}})
# Out:
# 2

# %%
list(db.Valdis_44.find({"hunger":{"$gt":9000}}))
# Out:
# [{'_id': ObjectId('5ec7db1ba8571231401e3eff'),
#   'hunger': 9005,
#   'food': ['potatoes', 'milk', 'chocolate']},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
# first match hunger > 9000 is updated with new values {"hunger":8050,"happiness":"great"}
db.Valdis_44.update_one({"hunger":{"$gt":9000}},{"$set": {"hunger":8050,"happiness":"great"}})
list(db.Valdis_44.find({"hunger":{"$gt":9000}}))
# Out:
# [{'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
list(db.Valdis_44.find({"hunger":{"$gt":8000}}))
# Out:
# [{'_id': ObjectId('5ec7db1ba8571231401e3eff'),
#   'hunger': 8050,
#   'food': ['potatoes', 'milk', 'chocolate'],
#   'happiness': 'great'},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'}]

# %%
catsraw = """Oliver
Leo
Milo
Charlie
Max
Jack
Simba"""
cats = catsraw.split()
cats
# Out:
# ['Oliver', 'Leo', 'Milo', 'Charlie', 'Max', 'Jack', 'Simba']

# %%
db['Valdis_cats'].insert_one({"catname":cat,"mice_caught":random.randint(1,10)})
list(db.Valdis_cats.find({}))
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10}]

# %%
for cat in cats:
    # if we had a lot of data we might want to use insert_many especially with a remote database
    db.Valdis_44.insert_one({"catname":cat,"mice_caught":random.randint(1,10)})
list(db.Valdis_44.find({}))
# Out:
# [{'_id': ObjectId('5ec7d945a8571231401e3ef8'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d948a8571231401e3ef9'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7d94ba8571231401e3efa'),
#   'happiness': [1, 2, 100, 'unlimited']},
#  {'_id': ObjectId('5ec7da49a8571231401e3efc'), 'happiness': 'Amazing'},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efd'),
#   'somekey': 'somevalue',
#   'anotherkey': 4444},
#  {'_id': ObjectId('5ec7da6ca8571231401e3efe'),
#   'anotherkey': 334324,
#   'differentkey': [3, 2, 324, 32, 4234, 'Valdis']},
#  {'_id': ObjectId('5ec7db1ba8571231401e3eff'),
#   'hunger': 8050,
#   'food': ['potatoes', 'milk', 'chocolate'],
#   'happiness': 'great'},
#  {'_id': ObjectId('5ec7e8cc643e776de1ac39e8'),
#   'hunger': 9001,
#   'school': 'Accenture'},
#  {'_id': ObjectId('5ec7decfa8571231401e3f00'),
#   'catname': 'Oliver',
#   'mice_caught': 5},
#  {'_id': ObjectId('5ec7decfa8571231401e3f01'),
#   'catname': 'Leo',
#   'mice_caught': 7},
#  {'_id': ObjectId('5ec7decfa8571231401e3f02'),
#   'catname': 'Milo',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7decfa8571231401e3f03'),
#   'catname': 'Charlie',
#   'mice_caught': 4},
#  {'_id': ObjectId('5ec7decfa8571231401e3f04'),
#   'catname': 'Max',
#   'mice_caught': 1},
#  {'_id': ObjectId('5ec7decfa8571231401e3f05'),
#   'catname': 'Jack',
#   'mice_caught': 4},
#  {'_id': ObjectId('5ec7decfa8571231401e3f06'),
#   'catname': 'Simba',
#   'mice_caught': 6},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f07'),
#   'catname': 'Oliver',
#   'mice_caught': 1},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f08'),
#   'catname': 'Leo',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f09'),
#   'catname': 'Milo',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f0a'),
#   'catname': 'Charlie',
#   'mice_caught': 4},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f0b'),
#   'catname': 'Max',
#   'mice_caught': 5},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f0c'),
#   'catname': 'Jack',
#   'mice_caught': 6},
#  {'_id': ObjectId('5ec7dee9a8571231401e3f0d'),
#   'catname': 'Simba',
#   'mice_caught': 1}]

# %%
try:
    db.create_collection("Mana_jauna_kolekcija_M22") # so only once otherwise an error will be thrown
except:
    print("Db already exists!")
db.list_collection_names()
# Out:
# Db already exists!
# ['Mana_jauna_kolekcija_M22',
#  'Julia M22',
#  'M_Beikerts_M22',
#  'Arturs_cats',
#  'Pavels.S',
#  'mynewcoll',
#  'mycollname',
#  'JelenaS_M22_1090',
#  'Arturs_M22',
#  'Ilze02',
#  'Zanes_M22',
#  'Viesturs_M22',
#  'MyRandomColl_3072',
#  'Aija O_M22',
#  'Julia_M22',
#  'Valdis_cats',
#  'system.indexes',
#  'moc',
#  'big',
#  'mock',
#  'Mana_Julias_datubaze_22',
#  'Liene1',
#  'Valdis_44',
#  'Julia_22',
#  'small',
#  'Sana',
#  'Julia_Cats']

# %%
for cat in cats:
    # if we had a lot of data we might want to use insert_many especially with a remote database
    db.Valdis_cats.insert_one({"catname":cat,"mice_caught":random.randint(1,10)})
list(db.Valdis_cats.find({}))
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f0f'),
#   'catname': 'Oliver',
#   'mice_caught': 7},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f10'),
#   'catname': 'Leo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f11'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f12'),
#   'catname': 'Charlie',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f13'),
#   'catname': 'Max',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f14'),
#   'catname': 'Jack',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f15'),
#   'catname': 'Simba',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f16'),
#   'catname': 'Oliver',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f17'),
#   'catname': 'Leo',
#   'mice_caught': 1},
#  {'_id': ObjectId('5ec7e378a8571231401e3f18'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e378a8571231401e3f19'),
#   'catname': 'Charlie',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1a'),
#   'catname': 'Max',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1b'),
#   'catname': 'Jack',
#   'mice_caught': 5},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1c'),
#   'catname': 'Simba',
#   'mice_caught': 7}]

# %%
import pandas as pd

# %%
reslist = list(db.Valdis_cats.find({}))
reslist
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f0f'),
#   'catname': 'Oliver',
#   'mice_caught': 7},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f10'),
#   'catname': 'Leo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f11'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f12'),
#   'catname': 'Charlie',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f13'),
#   'catname': 'Max',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f14'),
#   'catname': 'Jack',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f15'),
#   'catname': 'Simba',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f16'),
#   'catname': 'Oliver',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f17'),
#   'catname': 'Leo',
#   'mice_caught': 1},
#  {'_id': ObjectId('5ec7e378a8571231401e3f18'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e378a8571231401e3f19'),
#   'catname': 'Charlie',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1a'),
#   'catname': 'Max',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1b'),
#   'catname': 'Jack',
#   'mice_caught': 5},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1c'),
#   'catname': 'Simba',
#   'mice_caught': 7}]

# %%
df = pd.DataFrame(reslist)
df
# Out:
#                          _id  catname  mice_caught
# 0   5ec7e140a8571231401e3f0e    Simba           10
# 1   5ec7e36aa8571231401e3f0f   Oliver            7
# 2   5ec7e36aa8571231401e3f10      Leo            8
# 3   5ec7e36aa8571231401e3f11     Milo            8
# 4   5ec7e36aa8571231401e3f12  Charlie            9
# 5   5ec7e36aa8571231401e3f13      Max            9
# 6   5ec7e36aa8571231401e3f14     Jack            8
# 7   5ec7e36aa8571231401e3f15    Simba            2
# 8   5ec7e378a8571231401e3f16   Oliver            2
# 9   5ec7e378a8571231401e3f17      Leo            1
# 10  5ec7e378a8571231401e3f18     Milo            8
# 11  5ec7e378a8571231401e3f19  Charlie           10
# 12  5ec7e378a8571231401e3f1a      Max            2
# 13  5ec7e378a8571231401e3f1b     Jack            5
# 14  5ec7e378a8571231401e3f1c    Simba            7

# %%
df2 = pd.DataFrame(db.Valdis_cats.find({})) #turns out Pandas know how to process MongoDB Cursor
df2.head()
# Out:
#                         _id  catname  mice_caught
# 0  5ec7e140a8571231401e3f0e    Simba           10
# 1  5ec7e36aa8571231401e3f0f   Oliver            7
# 2  5ec7e36aa8571231401e3f10      Leo            8
# 3  5ec7e36aa8571231401e3f11     Milo            8
# 4  5ec7e36aa8571231401e3f12  Charlie            9

# %%
list(db.Valdis_cats.find({"catname":"Simba"}))
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f15'),
#   'catname': 'Simba',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1c'),
#   'catname': 'Simba',
#   'mice_caught': 7}]

# %%
db.Valdis_cats.update_many({"catname":"Simba"},{"$set": {"evil_uncle":1}})
list(db.Valdis_cats.find({"catname":"Simba"}))
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10,
#   'evil_uncle': 1},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f15'),
#   'catname': 'Simba',
#   'mice_caught': 2,
#   'evil_uncle': 1},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1c'),
#   'catname': 'Simba',
#   'mice_caught': 7,
#   'evil_uncle': 1}]

# %%
df3 = pd.DataFrame(db.Valdis_cats.find({})) #turns out even missing keys are processed by Pandas
df3
# Out:
#                          _id  catname  evil_uncle  mice_caught
# 0   5ec7e140a8571231401e3f0e    Simba         1.0           10
# 1   5ec7e36aa8571231401e3f0f   Oliver         NaN            7
# 2   5ec7e36aa8571231401e3f10      Leo         NaN            8
# 3   5ec7e36aa8571231401e3f11     Milo         NaN            8
# 4   5ec7e36aa8571231401e3f12  Charlie         NaN            9
# 5   5ec7e36aa8571231401e3f13      Max         NaN            9
# 6   5ec7e36aa8571231401e3f14     Jack         NaN            8
# 7   5ec7e36aa8571231401e3f15    Simba         1.0            2
# 8   5ec7e378a8571231401e3f16   Oliver         NaN            2
# 9   5ec7e378a8571231401e3f17      Leo         NaN            1
# 10  5ec7e378a8571231401e3f18     Milo         NaN            8
# 11  5ec7e378a8571231401e3f19  Charlie         NaN           10
# 12  5ec7e378a8571231401e3f1a      Max         NaN            2
# 13  5ec7e378a8571231401e3f1b     Jack         NaN            5
# 14  5ec7e378a8571231401e3f1c    Simba         1.0            7

# %%
mycats = list(db.Valdis_cats.find({}))
mycats
# Out:
# [{'_id': ObjectId('5ec7e140a8571231401e3f0e'),
#   'catname': 'Simba',
#   'mice_caught': 10,
#   'evil_uncle': 1},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f0f'),
#   'catname': 'Oliver',
#   'mice_caught': 7},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f10'),
#   'catname': 'Leo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f11'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f12'),
#   'catname': 'Charlie',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f13'),
#   'catname': 'Max',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f14'),
#   'catname': 'Jack',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f15'),
#   'catname': 'Simba',
#   'mice_caught': 2,
#   'evil_uncle': 1},
#  {'_id': ObjectId('5ec7e378a8571231401e3f16'),
#   'catname': 'Oliver',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f17'),
#   'catname': 'Leo',
#   'mice_caught': 1},
#  {'_id': ObjectId('5ec7e378a8571231401e3f18'),
#   'catname': 'Milo',
#   'mice_caught': 8},
#  {'_id': ObjectId('5ec7e378a8571231401e3f19'),
#   'catname': 'Charlie',
#   'mice_caught': 10},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1a'),
#   'catname': 'Max',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1b'),
#   'catname': 'Jack',
#   'mice_caught': 5},
#  {'_id': ObjectId('5ec7e378a8571231401e3f1c'),
#   'catname': 'Simba',
#   'mice_caught': 7,
#   'evil_uncle': 1}]

# %%
mylicats = [cat for cat in mycats if "li" in cat.get('catname')]
mylicats
# Out:
# [{'_id': ObjectId('5ec7e36aa8571231401e3f0f'),
#   'catname': 'Oliver',
#   'mice_caught': 7},
#  {'_id': ObjectId('5ec7e36aa8571231401e3f12'),
#   'catname': 'Charlie',
#   'mice_caught': 9},
#  {'_id': ObjectId('5ec7e378a8571231401e3f16'),
#   'catname': 'Oliver',
#   'mice_caught': 2},
#  {'_id': ObjectId('5ec7e378a8571231401e3f19'),
#   'catname': 'Charlie',
#   'mice_caught': 10}]

# %%
type(db.Valdis_cats.find({}))
# Out:
# pymongo.cursor.Cursor

# %%
df.describe()
# Out:
#        mice_caught
# count    15.000000
# mean      6.400000
# std       3.157757
# min       1.000000
# 25%       3.500000
# 50%       8.000000
# 75%       8.500000
# max      10.000000

# %%
db.Valdis_44.update_one({"_id":ObjectId('5e5a3a56a857120a28e9b238')},{"$set": {"hunger":18050,"happiness":"great"}})
db.Valdis_44.count_documents({"hunger":{"$gt":9000}})
# Out:
# 1

# %%
# we can get all documents which have hunger key
reslist = list(db.Valdis_44.find({"hunger":{ "$exists": True }}))
reslist
# Out:
# [{'_id': ObjectId('5e5a3a1ba857120a28e9b236'), 'hunger': 9000},
#  {'_id': ObjectId('5e5a3a21a857120a28e9b237'), 'hunger': 9000},
#  {'_id': ObjectId('5e5a3a57a857120a28e9b239'), 'hunger': 9000},
#  {'_id': ObjectId('5e5a3c62278f777756a1be66'), 'hunger': 9000},
#  {'_id': ObjectId('5e5a3cf77896ae1849982f39'), 'hunger': 9000},
#  {'_id': ObjectId('5e5a3f6aa857120a28e9b23f'),
#   'hunger': 8000,
#   'school': 'Accenture',
#   'happiness': 'great'},
#  {'_id': ObjectId('5e5a48bfa857120a28e9b240'),
#   'hunger': 8050,
#   'school': 'Accenture',
#   'happiness': 'great'},
#  {'_id': ObjectId('5e5a48d7a857120a28e9b241'),
#   'hunger': 8000,
#   'school': 'Accenture',
#   'happiness': 'great'},
#  {'_id': ObjectId('5e5a3a56a857120a28e9b238'),
#   'hunger': 18050,
#   'happiness': 'great'}]

# %%
reslist[0]['hunger']
# Out:
# 9000

# %%
total = 0
for el in reslist:
    total += el['hunger']
total, total/len(reslist)
# Out:
# (87100, 9677.777777777777)

# %%
import pandas as pd

# %%
df = pd.DataFrame(reslist)
df
# Out:
#                         _id happiness  hunger     school
# 0  5e5a3a1ba857120a28e9b236       NaN    9000        NaN
# 1  5e5a3a21a857120a28e9b237       NaN    9000        NaN
# 2  5e5a3a56a857120a28e9b238       NaN    9000        NaN
# 3  5e5a3a57a857120a28e9b239       NaN    9000        NaN
# 4  5e5a3c62278f777756a1be66       NaN    9000        NaN
# 5  5e5a3cf77896ae1849982f39       NaN    9000        NaN
# 6  5e5a3f6aa857120a28e9b23f     great    8000  Accenture
# 7  5e5a48bfa857120a28e9b240     great    8050  Accenture
# 8  5e5a48d7a857120a28e9b241     great    8000  Accenture

# %%
df['hunger'].describe()
# Out:
# count       9.000000
# mean     8672.222222
# std       491.878485
# min      8000.000000
# 25%      8050.000000
# 50%      9000.000000
# 75%      9000.000000
# max      9000.000000
# Name: hunger, dtype: float64

# %%
from bson.objectid import ObjectId

# %%
mock = db['valdis_customer_data']
mock.insert_one({"Name":"Valdis"})
list(mock.find({}))
# Out:
# [{'_id': ObjectId('5ec7e926a8571231401e3f1d'), 'Name': 'Valdis'}]

# %%
list(mock.find({}))
# Out:
# [{'_id': ObjectId('5ec7e926a8571231401e3f1d'), 'Name': 'Valdis'}]

# %%
with open('MOCK_DATA.json') as f:
    mydata = json.load(f)
mydata[:5],len(mydata)
# Out:
# ([{'id': 1,
#    'first_name': 'Valdis',
#    'last_name': 'Northgraves',
#    'email': 'vnorthgraves0@japanpost.jp',
#    'gender': 'Male',
#    'ip_address': '182.131.114.164'},
#   {'id': 2,
#    'first_name': 'Valdis',
#    'last_name': 'Helsdon',
#    'email': 'vhelsdon1@flickr.com',
#    'gender': 'Female',
#    'ip_address': '89.230.232.169'},
#   {'id': 3,
#    'first_name': 'Valdis',
#    'last_name': 'McCombe',
#    'email': 'vmccombe2@squidoo.com',
#    'gender': 'Male',
#    'ip_address': '1.99.23.215'},
#   {'id': 4,
#    'first_name': 'Valdis',
#    'last_name': 'Alltimes',
#    'email': 'valltimes3@statcounter.com',
#    'gender': 'Male',
#    'ip_address': '156.132.196.74'},
#   {'id': 5,
#    'first_name': 'Valdis',
#    'last_name': 'Joburn',
#    'email': 'vjoburn4@nasa.gov',
#    'gender': 'Male',
#    'ip_address': '125.225.54.96'}],
#  10)

# %%
rawjson = """[{"id":1,"first_name":"Valdis","last_name":"Northgraves","email":"vnorthgraves0@japanpost.jp","gender":"Male","ip_address":"182.131.114.164"},
{"id":2,"first_name":"Valdis","last_name":"Helsdon","email":"vhelsdon1@flickr.com","gender":"Female","ip_address":"89.230.232.169"},
{"id":3,"first_name":"Valdis","last_name":"McCombe","email":"vmccombe2@squidoo.com","gender":"Male","ip_address":"1.99.23.215"},
{"id":4,"first_name":"Valdis","last_name":"Alltimes","email":"valltimes3@statcounter.com","gender":"Male","ip_address":"156.132.196.74"},
{"id":5,"first_name":"Valdis","last_name":"Joburn","email":"vjoburn4@nasa.gov","gender":"Male","ip_address":"125.225.54.96"},
{"id":6,"first_name":"Valdis","last_name":"Pethybridge","email":"vpethybridge5@macromedia.com","gender":"Female","ip_address":"97.78.69.199"},
{"id":7,"first_name":"Valdis","last_name":"Windows","email":"vwindows6@tinypic.com","gender":"Female","ip_address":"223.218.19.48"},
{"id":8,"first_name":"Valdis","last_name":"Kedslie","email":"vkedslie7@eepurl.com","gender":"Male","ip_address":"57.126.72.176"},
{"id":9,"first_name":"Valdis","last_name":"Elkin","email":"velkin8@bluehost.com","gender":"Female","ip_address":"53.197.46.172"},
{"id":10,"first_name":"Valdis","last_name":"Probets","email":"vprobets9@barnesandnoble.com","gender":"Female","ip_address":"192.251.86.110"}]"""

# %%
mydata2 = json.loads(rawjson)
mydata2
# Out:
# [{'id': 1,
#   'first_name': 'Valdis',
#   'last_name': 'Northgraves',
#   'email': 'vnorthgraves0@japanpost.jp',
#   'gender': 'Male',
#   'ip_address': '182.131.114.164'},
#  {'id': 2,
#   'first_name': 'Valdis',
#   'last_name': 'Helsdon',
#   'email': 'vhelsdon1@flickr.com',
#   'gender': 'Female',
#   'ip_address': '89.230.232.169'},
#  {'id': 3,
#   'first_name': 'Valdis',
#   'last_name': 'McCombe',
#   'email': 'vmccombe2@squidoo.com',
#   'gender': 'Male',
#   'ip_address': '1.99.23.215'},
#  {'id': 4,
#   'first_name': 'Valdis',
#   'last_name': 'Alltimes',
#   'email': 'valltimes3@statcounter.com',
#   'gender': 'Male',
#   'ip_address': '156.132.196.74'},
#  {'id': 5,
#   'first_name': 'Valdis',
#   'last_name': 'Joburn',
#   'email': 'vjoburn4@nasa.gov',
#   'gender': 'Male',
#   'ip_address': '125.225.54.96'},
#  {'id': 6,
#   'first_name': 'Valdis',
#   'last_name': 'Pethybridge',
#   'email': 'vpethybridge5@macromedia.com',
#   'gender': 'Female',
#   'ip_address': '97.78.69.199'},
#  {'id': 7,
#   'first_name': 'Valdis',
#   'last_name': 'Windows',
#   'email': 'vwindows6@tinypic.com',
#   'gender': 'Female',
#   'ip_address': '223.218.19.48'},
#  {'id': 8,
#   'first_name': 'Valdis',
#   'last_name': 'Kedslie',
#   'email': 'vkedslie7@eepurl.com',
#   'gender': 'Male',
#   'ip_address': '57.126.72.176'},
#  {'id': 9,
#   'first_name': 'Valdis',
#   'last_name': 'Elkin',
#   'email': 'velkin8@bluehost.com',
#   'gender': 'Female',
#   'ip_address': '53.197.46.172'},
#  {'id': 10,
#   'first_name': 'Valdis',
#   'last_name': 'Probets',
#   'email': 'vprobets9@barnesandnoble.com',
#   'gender': 'Female',
#   'ip_address': '192.251.86.110'}]

# %%
mock.insert_many(mydata)
len(list(mock.find({})))
# Out:
# 21

# %%
import requests

# %%
res = requests.get("https://api.mockaroo.com/api/c77ba780?count=1000&key=58227cb0")
res.status_code
# Out:
# 200

# %%
bigdata = res.json() # requests includes json decoder.
len(bigdata)
# Out:
# 1000

# %%
bigcol = db['valdis_big_data4']
bigcol.insert_many(bigdata[:500]) # so decoded JSON can be inserted directly into PyMongo
bigcol.count_documents({})
# Out:
# 500

# %%
type(res.json())
# Out:
# list

# %%
type(bigdata)
# Out:
# list

# %%
bigcol.count_documents({})
# Out:
# 1000

# %%
mock.count_documents({})
# Out:
# 35

# %%
list(bigcol.find({"first_name":"Valdis"}))
# Out:
# [{'_id': ObjectId('5ec7e9d8a8571231401e3f32'),
#   'id': 1,
#   'first_name': 'Valdis',
#   'last_name': 'Spurdon',
#   'email': 'vspurdon0@facebook.com',
#   'gender': 'Male',
#   'ip_address': '212.126.254.134'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f33'),
#   'id': 2,
#   'first_name': 'Valdis',
#   'last_name': 'McGriele',
#   'email': 'vmcgriele1@vistaprint.com',
#   'gender': 'Female',
#   'ip_address': '27.92.30.238'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f34'),
#   'id': 3,
#   'first_name': 'Valdis',
#   'last_name': 'Kopp',
#   'email': 'vkopp2@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '170.70.15.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f35'),
#   'id': 4,
#   'first_name': 'Valdis',
#   'last_name': 'Blincow',
#   'email': 'vblincow3@ebay.com',
#   'gender': 'Male',
#   'ip_address': '148.154.59.138'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f36'),
#   'id': 5,
#   'first_name': 'Valdis',
#   'last_name': 'Demicoli',
#   'email': 'vdemicoli4@bloomberg.com',
#   'gender': 'Female',
#   'ip_address': '42.224.167.13'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f37'),
#   'id': 6,
#   'first_name': 'Valdis',
#   'last_name': 'Hayzer',
#   'email': 'vhayzer5@github.com',
#   'gender': 'Male',
#   'ip_address': '120.71.178.12'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f38'),
#   'id': 7,
#   'first_name': 'Valdis',
#   'last_name': 'Foskin',
#   'email': 'vfoskin6@mtv.com',
#   'gender': 'Male',
#   'ip_address': '108.246.192.214'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f39'),
#   'id': 8,
#   'first_name': 'Valdis',
#   'last_name': 'Nairy',
#   'email': 'vnairy7@yellowpages.com',
#   'gender': 'Female',
#   'ip_address': '185.82.141.113'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3a'),
#   'id': 9,
#   'first_name': 'Valdis',
#   'last_name': 'Housiaux',
#   'email': 'vhousiaux8@thetimes.co.uk',
#   'gender': 'Male',
#   'ip_address': '158.246.100.184'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3b'),
#   'id': 10,
#   'first_name': 'Valdis',
#   'last_name': 'Marchbank',
#   'email': 'vmarchbank9@1688.com',
#   'gender': 'Male',
#   'ip_address': '6.190.220.178'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3c'),
#   'id': 11,
#   'first_name': 'Valdis',
#   'last_name': 'Caldero',
#   'email': 'vcalderoa@ehow.com',
#   'gender': 'Female',
#   'ip_address': '21.184.138.109'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3d'),
#   'id': 12,
#   'first_name': 'Valdis',
#   'last_name': 'Tomala',
#   'email': 'vtomalab@infoseek.co.jp',
#   'gender': 'Female',
#   'ip_address': '218.184.112.115'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3e'),
#   'id': 13,
#   'first_name': 'Valdis',
#   'last_name': 'Attride',
#   'email': 'vattridec@tripadvisor.com',
#   'gender': 'Male',
#   'ip_address': '170.145.96.181'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3f'),
#   'id': 14,
#   'first_name': 'Valdis',
#   'last_name': 'Zavattiero',
#   'email': 'vzavattierod@hhs.gov',
#   'gender': 'Female',
#   'ip_address': '153.122.26.138'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f40'),
#   'id': 15,
#   'first_name': 'Valdis',
#   'last_name': 'Edlyn',
#   'email': 'vedlyne@gravatar.com',
#   'gender': 'Male',
#   'ip_address': '61.4.162.166'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f41'),
#   'id': 16,
#   'first_name': 'Valdis',
#   'last_name': 'Geeve',
#   'email': 'vgeevef@businessweek.com',
#   'gender': 'Female',
#   'ip_address': '162.158.92.148'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f42'),
#   'id': 17,
#   'first_name': 'Valdis',
#   'last_name': 'Ovenell',
#   'email': 'vovenellg@mtv.com',
#   'gender': 'Male',
#   'ip_address': '121.73.27.149'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f43'),
#   'id': 18,
#   'first_name': 'Valdis',
#   'last_name': 'Andrysek',
#   'email': 'vandrysekh@usnews.com',
#   'gender': 'Female',
#   'ip_address': '111.247.130.41'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f44'),
#   'id': 19,
#   'first_name': 'Valdis',
#   'last_name': 'Atwel',
#   'email': 'vatweli@fda.gov',
#   'gender': 'Male',
#   'ip_address': '158.165.16.76'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f45'),
#   'id': 20,
#   'first_name': 'Valdis',
#   'last_name': 'Dulanty',
#   'email': 'vdulantyj@163.com',
#   'gender': 'Male',
#   'ip_address': '34.49.220.21'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f46'),
#   'id': 21,
#   'first_name': 'Valdis',
#   'last_name': 'Andrewartha',
#   'email': 'vandrewarthak@free.fr',
#   'gender': 'Male',
#   'ip_address': '163.139.101.212'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f47'),
#   'id': 22,
#   'first_name': 'Valdis',
#   'last_name': 'Ruslinge',
#   'email': 'vruslingel@sfgate.com',
#   'gender': 'Male',
#   'ip_address': '126.23.216.114'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f48'),
#   'id': 23,
#   'first_name': 'Valdis',
#   'last_name': 'Phillpot',
#   'email': 'vphillpotm@paypal.com',
#   'gender': 'Male',
#   'ip_address': '113.146.67.222'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f49'),
#   'id': 24,
#   'first_name': 'Valdis',
#   'last_name': 'Stebbings',
#   'email': 'vstebbingsn@ning.com',
#   'gender': 'Male',
#   'ip_address': '217.189.225.127'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4a'),
#   'id': 25,
#   'first_name': 'Valdis',
#   'last_name': 'Donaway',
#   'email': 'vdonawayo@hc360.com',
#   'gender': 'Female',
#   'ip_address': '71.154.138.188'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4b'),
#   'id': 26,
#   'first_name': 'Valdis',
#   'last_name': 'Ruscoe',
#   'email': 'vruscoep@hao123.com',
#   'gender': 'Male',
#   'ip_address': '52.150.217.239'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4c'),
#   'id': 27,
#   'first_name': 'Valdis',
#   'last_name': 'Milmoe',
#   'email': 'vmilmoeq@vinaora.com',
#   'gender': 'Male',
#   'ip_address': '162.191.70.198'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4d'),
#   'id': 28,
#   'first_name': 'Valdis',
#   'last_name': 'Girtin',
#   'email': 'vgirtinr@skyrock.com',
#   'gender': 'Female',
#   'ip_address': '9.8.193.238'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4e'),
#   'id': 29,
#   'first_name': 'Valdis',
#   'last_name': 'Prandi',
#   'email': 'vprandis@wikispaces.com',
#   'gender': 'Male',
#   'ip_address': '131.101.199.253'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f4f'),
#   'id': 30,
#   'first_name': 'Valdis',
#   'last_name': 'Shotter',
#   'email': 'vshottert@foxnews.com',
#   'gender': 'Male',
#   'ip_address': '59.111.253.234'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f50'),
#   'id': 31,
#   'first_name': 'Valdis',
#   'last_name': 'Banaszkiewicz',
#   'email': 'vbanaszkiewiczu@businessweek.com',
#   'gender': 'Female',
#   'ip_address': '8.186.219.134'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f51'),
#   'id': 32,
#   'first_name': 'Valdis',
#   'last_name': 'Boots',
#   'email': 'vbootsv@gravatar.com',
#   'gender': 'Female',
#   'ip_address': '255.5.201.7'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f52'),
#   'id': 33,
#   'first_name': 'Valdis',
#   'last_name': 'Whetland',
#   'email': 'vwhetlandw@dion.ne.jp',
#   'gender': 'Female',
#   'ip_address': '199.0.4.210'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f53'),
#   'id': 34,
#   'first_name': 'Valdis',
#   'last_name': 'Harry',
#   'email': 'vharryx@merriam-webster.com',
#   'gender': 'Male',
#   'ip_address': '217.174.246.114'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f54'),
#   'id': 35,
#   'first_name': 'Valdis',
#   'last_name': 'Frigout',
#   'email': 'vfrigouty@slideshare.net',
#   'gender': 'Male',
#   'ip_address': '49.130.194.111'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f55'),
#   'id': 36,
#   'first_name': 'Valdis',
#   'last_name': 'Chesson',
#   'email': 'vchessonz@typepad.com',
#   'gender': 'Male',
#   'ip_address': '106.157.140.180'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f56'),
#   'id': 37,
#   'first_name': 'Valdis',
#   'last_name': 'Renault',
#   'email': 'vrenault10@multiply.com',
#   'gender': 'Female',
#   'ip_address': '185.210.50.241'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f57'),
#   'id': 38,
#   'first_name': 'Valdis',
#   'last_name': 'Grishin',
#   'email': 'vgrishin11@arstechnica.com',
#   'gender': 'Male',
#   'ip_address': '190.120.190.175'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f58'),
#   'id': 39,
#   'first_name': 'Valdis',
#   'last_name': 'Grieveson',
#   'email': 'vgrieveson12@163.com',
#   'gender': 'Female',
#   'ip_address': '207.178.92.122'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f59'),
#   'id': 40,
#   'first_name': 'Valdis',
#   'last_name': 'Pyvis',
#   'email': 'vpyvis13@hp.com',
#   'gender': 'Male',
#   'ip_address': '193.63.78.6'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5a'),
#   'id': 41,
#   'first_name': 'Valdis',
#   'last_name': 'Cartmail',
#   'email': 'vcartmail14@mapy.cz',
#   'gender': 'Female',
#   'ip_address': '183.70.104.74'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5b'),
#   'id': 42,
#   'first_name': 'Valdis',
#   'last_name': 'Nemchinov',
#   'email': 'vnemchinov15@feedburner.com',
#   'gender': 'Female',
#   'ip_address': '199.16.8.49'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5c'),
#   'id': 43,
#   'first_name': 'Valdis',
#   'last_name': 'Berth',
#   'email': 'vberth16@oracle.com',
#   'gender': 'Female',
#   'ip_address': '234.20.23.204'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5d'),
#   'id': 44,
#   'first_name': 'Valdis',
#   'last_name': 'Hammant',
#   'email': 'vhammant17@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '172.11.133.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5e'),
#   'id': 45,
#   'first_name': 'Valdis',
#   'last_name': 'Brayson',
#   'email': 'vbrayson18@plala.or.jp',
#   'gender': 'Male',
#   'ip_address': '201.146.44.136'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5f'),
#   'id': 46,
#   'first_name': 'Valdis',
#   'last_name': 'Tomney',
#   'email': 'vtomney19@istockphoto.com',
#   'gender': 'Female',
#   'ip_address': '187.235.49.245'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f60'),
#   'id': 47,
#   'first_name': 'Valdis',
#   'last_name': 'Bradford',
#   'email': 'vbradford1a@washington.edu',
#   'gender': 'Male',
#   'ip_address': '15.4.245.36'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f61'),
#   'id': 48,
#   'first_name': 'Valdis',
#   'last_name': 'Andreasen',
#   'email': 'vandreasen1b@unesco.org',
#   'gender': 'Male',
#   'ip_address': '184.189.42.139'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f62'),
#   'id': 49,
#   'first_name': 'Valdis',
#   'last_name': 'Dovey',
#   'email': 'vdovey1c@wikia.com',
#   'gender': 'Female',
#   'ip_address': '91.52.27.227'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f63'),
#   'id': 50,
#   'first_name': 'Valdis',
#   'last_name': 'Leahey',
#   'email': 'vleahey1d@163.com',
#   'gender': 'Male',
#   'ip_address': '148.46.99.77'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f64'),
#   'id': 51,
#   'first_name': 'Valdis',
#   'last_name': 'Murtagh',
#   'email': 'vmurtagh1e@wikipedia.org',
#   'gender': 'Male',
#   'ip_address': '127.209.10.42'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f65'),
#   'id': 52,
#   'first_name': 'Valdis',
#   'last_name': 'Mowlam',
#   'email': 'vmowlam1f@parallels.com',
#   'gender': 'Male',
#   'ip_address': '11.246.203.43'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f66'),
#   'id': 53,
#   'first_name': 'Valdis',
#   'last_name': 'Sondland',
#   'email': 'vsondland1g@who.int',
#   'gender': 'Male',
#   'ip_address': '224.79.166.130'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f67'),
#   'id': 54,
#   'first_name': 'Valdis',
#   'last_name': 'Hobgen',
#   'email': 'vhobgen1h@desdev.cn',
#   'gender': 'Male',
#   'ip_address': '160.212.3.116'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f68'),
#   'id': 55,
#   'first_name': 'Valdis',
#   'last_name': 'Riden',
#   'email': 'vriden1i@eepurl.com',
#   'gender': 'Female',
#   'ip_address': '212.101.122.19'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f69'),
#   'id': 56,
#   'first_name': 'Valdis',
#   'last_name': 'Blacksell',
#   'email': 'vblacksell1j@intel.com',
#   'gender': 'Male',
#   'ip_address': '108.172.236.118'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6a'),
#   'id': 57,
#   'first_name': 'Valdis',
#   'last_name': "O'Doherty",
#   'email': 'vodoherty1k@virginia.edu',
#   'gender': 'Female',
#   'ip_address': '34.248.199.160'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6b'),
#   'id': 58,
#   'first_name': 'Valdis',
#   'last_name': 'Monk',
#   'email': 'vmonk1l@patch.com',
#   'gender': 'Male',
#   'ip_address': '109.17.93.207'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6c'),
#   'id': 59,
#   'first_name': 'Valdis',
#   'last_name': 'Riccardo',
#   'email': 'vriccardo1m@walmart.com',
#   'gender': 'Female',
#   'ip_address': '224.118.218.151'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6d'),
#   'id': 60,
#   'first_name': 'Valdis',
#   'last_name': 'Lagne',
#   'email': 'vlagne1n@exblog.jp',
#   'gender': 'Male',
#   'ip_address': '203.128.64.186'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6e'),
#   'id': 61,
#   'first_name': 'Valdis',
#   'last_name': 'Tremethack',
#   'email': 'vtremethack1o@chron.com',
#   'gender': 'Female',
#   'ip_address': '254.10.196.41'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6f'),
#   'id': 62,
#   'first_name': 'Valdis',
#   'last_name': 'Tomkys',
#   'email': 'vtomkys1p@examiner.com',
#   'gender': 'Female',
#   'ip_address': '1.232.93.64'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f70'),
#   'id': 63,
#   'first_name': 'Valdis',
#   'last_name': 'Kerrod',
#   'email': 'vkerrod1q@quantcast.com',
#   'gender': 'Male',
#   'ip_address': '79.204.99.212'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f71'),
#   'id': 64,
#   'first_name': 'Valdis',
#   'last_name': 'Jacobsohn',
#   'email': 'vjacobsohn1r@surveymonkey.com',
#   'gender': 'Female',
#   'ip_address': '181.67.51.117'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f72'),
#   'id': 65,
#   'first_name': 'Valdis',
#   'last_name': 'Millins',
#   'email': 'vmillins1s@virginia.edu',
#   'gender': 'Male',
#   'ip_address': '160.105.75.208'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f73'),
#   'id': 66,
#   'first_name': 'Valdis',
#   'last_name': 'Lamboll',
#   'email': 'vlamboll1t@gmpg.org',
#   'gender': 'Female',
#   'ip_address': '252.189.242.54'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f74'),
#   'id': 67,
#   'first_name': 'Valdis',
#   'last_name': 'Lexa',
#   'email': 'vlexa1u@scientificamerican.com',
#   'gender': 'Male',
#   'ip_address': '223.193.103.87'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f75'),
#   'id': 68,
#   'first_name': 'Valdis',
#   'last_name': 'Fiske',
#   'email': 'vfiske1v@pen.io',
#   'gender': 'Male',
#   'ip_address': '207.146.231.30'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f76'),
#   'id': 69,
#   'first_name': 'Valdis',
#   'last_name': 'Oglevie',
#   'email': 'voglevie1w@jugem.jp',
#   'gender': 'Male',
#   'ip_address': '131.201.106.103'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f77'),
#   'id': 70,
#   'first_name': 'Valdis',
#   'last_name': 'Trobridge',
#   'email': 'vtrobridge1x@upenn.edu',
#   'gender': 'Male',
#   'ip_address': '87.102.26.53'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f78'),
#   'id': 71,
#   'first_name': 'Valdis',
#   'last_name': 'Turnell',
#   'email': 'vturnell1y@marketwatch.com',
#   'gender': 'Male',
#   'ip_address': '22.187.79.80'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f79'),
#   'id': 72,
#   'first_name': 'Valdis',
#   'last_name': 'Martensen',
#   'email': 'vmartensen1z@amazonaws.com',
#   'gender': 'Male',
#   'ip_address': '198.220.89.223'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7a'),
#   'id': 73,
#   'first_name': 'Valdis',
#   'last_name': 'Stratford',
#   'email': 'vstratford20@myspace.com',
#   'gender': 'Male',
#   'ip_address': '9.190.63.201'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7b'),
#   'id': 74,
#   'first_name': 'Valdis',
#   'last_name': 'Fagg',
#   'email': 'vfagg21@example.com',
#   'gender': 'Female',
#   'ip_address': '84.99.184.125'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7c'),
#   'id': 75,
#   'first_name': 'Valdis',
#   'last_name': 'Caughtry',
#   'email': 'vcaughtry22@dell.com',
#   'gender': 'Female',
#   'ip_address': '179.181.113.64'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7d'),
#   'id': 76,
#   'first_name': 'Valdis',
#   'last_name': 'Carville',
#   'email': 'vcarville23@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '49.228.112.23'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7e'),
#   'id': 77,
#   'first_name': 'Valdis',
#   'last_name': 'Volett',
#   'email': 'vvolett24@homestead.com',
#   'gender': 'Male',
#   'ip_address': '75.190.102.132'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7f'),
#   'id': 78,
#   'first_name': 'Valdis',
#   'last_name': 'Swidenbank',
#   'email': 'vswidenbank25@youtu.be',
#   'gender': 'Female',
#   'ip_address': '190.253.244.230'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f80'),
#   'id': 79,
#   'first_name': 'Valdis',
#   'last_name': 'Janaszewski',
#   'email': 'vjanaszewski26@a8.net',
#   'gender': 'Female',
#   'ip_address': '234.249.149.110'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f81'),
#   'id': 80,
#   'first_name': 'Valdis',
#   'last_name': 'Waplinton',
#   'email': 'vwaplinton27@cdbaby.com',
#   'gender': 'Female',
#   'ip_address': '174.22.33.125'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f82'),
#   'id': 81,
#   'first_name': 'Valdis',
#   'last_name': 'Rivitt',
#   'email': 'vrivitt28@com.com',
#   'gender': 'Male',
#   'ip_address': '212.12.179.197'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f83'),
#   'id': 82,
#   'first_name': 'Valdis',
#   'last_name': 'Moffatt',
#   'email': 'vmoffatt29@webeden.co.uk',
#   'gender': 'Female',
#   'ip_address': '47.72.98.169'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f84'),
#   'id': 83,
#   'first_name': 'Valdis',
#   'last_name': 'Folonin',
#   'email': 'vfolonin2a@theatlantic.com',
#   'gender': 'Male',
#   'ip_address': '54.135.187.177'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f85'),
#   'id': 84,
#   'first_name': 'Valdis',
#   'last_name': 'Kyles',
#   'email': 'vkyles2b@nydailynews.com',
#   'gender': 'Female',
#   'ip_address': '15.25.4.104'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f86'),
#   'id': 85,
#   'first_name': 'Valdis',
#   'last_name': 'Drakes',
#   'email': 'vdrakes2c@w3.org',
#   'gender': 'Female',
#   'ip_address': '243.247.203.194'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f87'),
#   'id': 86,
#   'first_name': 'Valdis',
#   'last_name': 'Chaffer',
#   'email': 'vchaffer2d@chicagotribune.com',
#   'gender': 'Male',
#   'ip_address': '32.68.113.113'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f88'),
#   'id': 87,
#   'first_name': 'Valdis',
#   'last_name': 'Tremmil',
#   'email': 'vtremmil2e@tiny.cc',
#   'gender': 'Female',
#   'ip_address': '61.39.46.114'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f89'),
#   'id': 88,
#   'first_name': 'Valdis',
#   'last_name': 'Pagelsen',
#   'email': 'vpagelsen2f@geocities.com',
#   'gender': 'Male',
#   'ip_address': '221.249.247.10'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8a'),
#   'id': 89,
#   'first_name': 'Valdis',
#   'last_name': 'Brauner',
#   'email': 'vbrauner2g@hp.com',
#   'gender': 'Male',
#   'ip_address': '183.204.132.186'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8b'),
#   'id': 90,
#   'first_name': 'Valdis',
#   'last_name': 'Manktelow',
#   'email': 'vmanktelow2h@last.fm',
#   'gender': 'Female',
#   'ip_address': '123.200.245.37'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8c'),
#   'id': 91,
#   'first_name': 'Valdis',
#   'last_name': 'Tassel',
#   'email': 'vtassel2i@fastcompany.com',
#   'gender': 'Male',
#   'ip_address': '193.83.66.253'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8d'),
#   'id': 92,
#   'first_name': 'Valdis',
#   'last_name': 'Ilyinykh',
#   'email': 'vilyinykh2j@sciencedirect.com',
#   'gender': 'Male',
#   'ip_address': '101.82.164.166'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8e'),
#   'id': 93,
#   'first_name': 'Valdis',
#   'last_name': 'Hotson',
#   'email': 'vhotson2k@xrea.com',
#   'gender': 'Female',
#   'ip_address': '163.192.207.41'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f8f'),
#   'id': 94,
#   'first_name': 'Valdis',
#   'last_name': 'Baldassi',
#   'email': 'vbaldassi2l@fema.gov',
#   'gender': 'Female',
#   'ip_address': '176.214.62.67'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f90'),
#   'id': 95,
#   'first_name': 'Valdis',
#   'last_name': 'Howerd',
#   'email': 'vhowerd2m@creativecommons.org',
#   'gender': 'Male',
#   'ip_address': '79.223.103.168'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f91'),
#   'id': 96,
#   'first_name': 'Valdis',
#   'last_name': 'Vizor',
#   'email': 'vvizor2n@canalblog.com',
#   'gender': 'Male',
#   'ip_address': '72.72.64.109'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f92'),
#   'id': 97,
#   'first_name': 'Valdis',
#   'last_name': 'Bayles',
#   'email': 'vbayles2o@ovh.net',
#   'gender': 'Male',
#   'ip_address': '190.99.45.202'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f93'),
#   'id': 98,
#   'first_name': 'Valdis',
#   'last_name': 'Primo',
#   'email': 'vprimo2p@facebook.com',
#   'gender': 'Male',
#   'ip_address': '107.66.126.227'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f94'),
#   'id': 99,
#   'first_name': 'Valdis',
#   'last_name': 'Ivannikov',
#   'email': 'vivannikov2q@reference.com',
#   'gender': 'Male',
#   'ip_address': '195.178.215.129'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f95'),
#   'id': 100,
#   'first_name': 'Valdis',
#   'last_name': 'Beasleigh',
#   'email': 'vbeasleigh2r@wsj.com',
#   'gender': 'Male',
#   'ip_address': '41.1.29.193'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f96'),
#   'id': 101,
#   'first_name': 'Valdis',
#   'last_name': 'Awcoate',
#   'email': 'vawcoate2s@bizjournals.com',
#   'gender': 'Male',
#   'ip_address': '172.90.220.126'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f97'),
#   'id': 102,
#   'first_name': 'Valdis',
#   'last_name': 'Collis',
#   'email': 'vcollis2t@skyrock.com',
#   'gender': 'Female',
#   'ip_address': '82.12.37.45'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f98'),
#   'id': 103,
#   'first_name': 'Valdis',
#   'last_name': 'Pitbladdo',
#   'email': 'vpitbladdo2u@dot.gov',
#   'gender': 'Male',
#   'ip_address': '161.220.154.142'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f99'),
#   'id': 104,
#   'first_name': 'Valdis',
#   'last_name': 'Simonnot',
#   'email': 'vsimonnot2v@wikispaces.com',
#   'gender': 'Female',
#   'ip_address': '120.66.50.244'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9a'),
#   'id': 105,
#   'first_name': 'Valdis',
#   'last_name': 'Crackel',
#   'email': 'vcrackel2w@jiathis.com',
#   'gender': 'Female',
#   'ip_address': '6.99.54.11'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9b'),
#   'id': 106,
#   'first_name': 'Valdis',
#   'last_name': 'Sainter',
#   'email': 'vsainter2x@artisteer.com',
#   'gender': 'Male',
#   'ip_address': '77.31.218.173'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9c'),
#   'id': 107,
#   'first_name': 'Valdis',
#   'last_name': 'Van Dalen',
#   'email': 'vvandalen2y@last.fm',
#   'gender': 'Male',
#   'ip_address': '173.9.217.229'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9d'),
#   'id': 108,
#   'first_name': 'Valdis',
#   'last_name': 'Rhyme',
#   'email': 'vrhyme2z@nationalgeographic.com',
#   'gender': 'Female',
#   'ip_address': '53.39.47.182'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9e'),
#   'id': 109,
#   'first_name': 'Valdis',
#   'last_name': 'Blythe',
#   'email': 'vblythe30@amazon.com',
#   'gender': 'Male',
#   'ip_address': '248.125.24.94'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f9f'),
#   'id': 110,
#   'first_name': 'Valdis',
#   'last_name': 'Haddon',
#   'email': 'vhaddon31@miibeian.gov.cn',
#   'gender': 'Female',
#   'ip_address': '237.239.173.224'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa0'),
#   'id': 111,
#   'first_name': 'Valdis',
#   'last_name': 'Leetham',
#   'email': 'vleetham32@dailymail.co.uk',
#   'gender': 'Female',
#   'ip_address': '51.166.216.30'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa1'),
#   'id': 112,
#   'first_name': 'Valdis',
#   'last_name': 'Steane',
#   'email': 'vsteane33@narod.ru',
#   'gender': 'Male',
#   'ip_address': '153.120.5.165'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa2'),
#   'id': 113,
#   'first_name': 'Valdis',
#   'last_name': 'Fiveash',
#   'email': 'vfiveash34@comsenz.com',
#   'gender': 'Male',
#   'ip_address': '182.202.114.70'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa3'),
#   'id': 114,
#   'first_name': 'Valdis',
#   'last_name': 'de Villier',
#   'email': 'vdevillier35@slate.com',
#   'gender': 'Female',
#   'ip_address': '253.249.41.26'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa4'),
#   'id': 115,
#   'first_name': 'Valdis',
#   'last_name': 'Chidzoy',
#   'email': 'vchidzoy36@tuttocitta.it',
#   'gender': 'Female',
#   'ip_address': '48.157.195.72'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa5'),
#   'id': 116,
#   'first_name': 'Valdis',
#   'last_name': 'Shiel',
#   'email': 'vshiel37@fda.gov',
#   'gender': 'Male',
#   'ip_address': '113.197.171.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa6'),
#   'id': 117,
#   'first_name': 'Valdis',
#   'last_name': 'Hearson',
#   'email': 'vhearson38@disqus.com',
#   'gender': 'Male',
#   'ip_address': '24.72.55.104'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa7'),
#   'id': 118,
#   'first_name': 'Valdis',
#   'last_name': 'Cocksedge',
#   'email': 'vcocksedge39@themeforest.net',
#   'gender': 'Female',
#   'ip_address': '86.94.111.210'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa8'),
#   'id': 119,
#   'first_name': 'Valdis',
#   'last_name': 'Yea',
#   'email': 'vyea3a@cbsnews.com',
#   'gender': 'Female',
#   'ip_address': '104.101.43.224'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fa9'),
#   'id': 120,
#   'first_name': 'Valdis',
#   'last_name': 'Sahnow',
#   'email': 'vsahnow3b@slate.com',
#   'gender': 'Male',
#   'ip_address': '137.35.107.244'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3faa'),
#   'id': 121,
#   'first_name': 'Valdis',
#   'last_name': 'Dewdney',
#   'email': 'vdewdney3c@reddit.com',
#   'gender': 'Male',
#   'ip_address': '146.115.131.190'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fab'),
#   'id': 122,
#   'first_name': 'Valdis',
#   'last_name': 'Cryer',
#   'email': 'vcryer3d@technorati.com',
#   'gender': 'Female',
#   'ip_address': '180.82.238.224'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fac'),
#   'id': 123,
#   'first_name': 'Valdis',
#   'last_name': 'Midgley',
#   'email': 'vmidgley3e@nytimes.com',
#   'gender': 'Female',
#   'ip_address': '179.240.221.109'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fad'),
#   'id': 124,
#   'first_name': 'Valdis',
#   'last_name': 'Chatwood',
#   'email': 'vchatwood3f@mysql.com',
#   'gender': 'Male',
#   'ip_address': '165.63.157.188'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fae'),
#   'id': 125,
#   'first_name': 'Valdis',
#   'last_name': 'Graeser',
#   'email': 'vgraeser3g@auda.org.au',
#   'gender': 'Female',
#   'ip_address': '30.249.192.89'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3faf'),
#   'id': 126,
#   'first_name': 'Valdis',
#   'last_name': 'Hannabuss',
#   'email': 'vhannabuss3h@sogou.com',
#   'gender': 'Male',
#   'ip_address': '16.112.198.55'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb0'),
#   'id': 127,
#   'first_name': 'Valdis',
#   'last_name': 'Ivantsov',
#   'email': 'vivantsov3i@shareasale.com',
#   'gender': 'Female',
#   'ip_address': '3.106.229.182'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb1'),
#   'id': 128,
#   'first_name': 'Valdis',
#   'last_name': 'Luff',
#   'email': 'vluff3j@apple.com',
#   'gender': 'Female',
#   'ip_address': '147.19.127.142'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb2'),
#   'id': 129,
#   'first_name': 'Valdis',
#   'last_name': 'Farrow',
#   'email': 'vfarrow3k@google.com.br',
#   'gender': 'Male',
#   'ip_address': '123.51.162.126'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb3'),
#   'id': 130,
#   'first_name': 'Valdis',
#   'last_name': 'Colin',
#   'email': 'vcolin3l@typepad.com',
#   'gender': 'Male',
#   'ip_address': '236.117.155.214'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb4'),
#   'id': 131,
#   'first_name': 'Valdis',
#   'last_name': 'Clines',
#   'email': 'vclines3m@t.co',
#   'gender': 'Male',
#   'ip_address': '25.173.15.40'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb5'),
#   'id': 132,
#   'first_name': 'Valdis',
#   'last_name': 'Greensall',
#   'email': 'vgreensall3n@earthlink.net',
#   'gender': 'Male',
#   'ip_address': '185.16.114.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb6'),
#   'id': 133,
#   'first_name': 'Valdis',
#   'last_name': 'Brookz',
#   'email': 'vbrookz3o@com.com',
#   'gender': 'Female',
#   'ip_address': '252.39.242.2'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb7'),
#   'id': 134,
#   'first_name': 'Valdis',
#   'last_name': 'Benza',
#   'email': 'vbenza3p@webnode.com',
#   'gender': 'Female',
#   'ip_address': '250.166.53.251'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb8'),
#   'id': 135,
#   'first_name': 'Valdis',
#   'last_name': 'Dradey',
#   'email': 'vdradey3q@paginegialle.it',
#   'gender': 'Male',
#   'ip_address': '96.94.216.39'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fb9'),
#   'id': 136,
#   'first_name': 'Valdis',
#   'last_name': 'Cluatt',
#   'email': 'vcluatt3r@myspace.com',
#   'gender': 'Female',
#   'ip_address': '144.76.119.242'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fba'),
#   'id': 137,
#   'first_name': 'Valdis',
#   'last_name': 'Zanini',
#   'email': 'vzanini3s@marketwatch.com',
#   'gender': 'Female',
#   'ip_address': '57.153.92.148'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbb'),
#   'id': 138,
#   'first_name': 'Valdis',
#   'last_name': 'Gow',
#   'email': 'vgow3t@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '166.216.99.125'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbc'),
#   'id': 139,
#   'first_name': 'Valdis',
#   'last_name': 'Kennermann',
#   'email': 'vkennermann3u@archive.org',
#   'gender': 'Female',
#   'ip_address': '36.56.154.121'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbd'),
#   'id': 140,
#   'first_name': 'Valdis',
#   'last_name': 'McGilroy',
#   'email': 'vmcgilroy3v@hexun.com',
#   'gender': 'Male',
#   'ip_address': '76.33.104.143'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbe'),
#   'id': 141,
#   'first_name': 'Valdis',
#   'last_name': 'Kembrey',
#   'email': 'vkembrey3w@time.com',
#   'gender': 'Male',
#   'ip_address': '168.193.91.124'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbf'),
#   'id': 142,
#   'first_name': 'Valdis',
#   'last_name': 'Meatyard',
#   'email': 'vmeatyard3x@qq.com',
#   'gender': 'Female',
#   'ip_address': '33.249.37.244'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc0'),
#   'id': 143,
#   'first_name': 'Valdis',
#   'last_name': 'Jeannequin',
#   'email': 'vjeannequin3y@cafepress.com',
#   'gender': 'Female',
#   'ip_address': '248.189.142.45'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc1'),
#   'id': 144,
#   'first_name': 'Valdis',
#   'last_name': 'Draude',
#   'email': 'vdraude3z@kickstarter.com',
#   'gender': 'Female',
#   'ip_address': '30.220.58.109'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc2'),
#   'id': 145,
#   'first_name': 'Valdis',
#   'last_name': 'Dunrige',
#   'email': 'vdunrige40@google.nl',
#   'gender': 'Male',
#   'ip_address': '58.226.87.163'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc3'),
#   'id': 146,
#   'first_name': 'Valdis',
#   'last_name': 'Rushton',
#   'email': 'vrushton41@who.int',
#   'gender': 'Male',
#   'ip_address': '144.206.105.13'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc4'),
#   'id': 147,
#   'first_name': 'Valdis',
#   'last_name': 'Gianolo',
#   'email': 'vgianolo42@cbslocal.com',
#   'gender': 'Male',
#   'ip_address': '228.149.222.150'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc5'),
#   'id': 148,
#   'first_name': 'Valdis',
#   'last_name': 'Everist',
#   'email': 'veverist43@msu.edu',
#   'gender': 'Female',
#   'ip_address': '42.225.142.28'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc6'),
#   'id': 149,
#   'first_name': 'Valdis',
#   'last_name': 'Harding',
#   'email': 'vharding44@alexa.com',
#   'gender': 'Male',
#   'ip_address': '14.244.250.68'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc7'),
#   'id': 150,
#   'first_name': 'Valdis',
#   'last_name': 'Thursby',
#   'email': 'vthursby45@cafepress.com',
#   'gender': 'Female',
#   'ip_address': '250.167.3.222'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc8'),
#   'id': 151,
#   'first_name': 'Valdis',
#   'last_name': 'Titley',
#   'email': 'vtitley46@i2i.jp',
#   'gender': 'Female',
#   'ip_address': '125.71.219.186'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc9'),
#   'id': 152,
#   'first_name': 'Valdis',
#   'last_name': 'Rutigliano',
#   'email': 'vrutigliano47@cyberchimps.com',
#   'gender': 'Male',
#   'ip_address': '197.34.220.25'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fca'),
#   'id': 153,
#   'first_name': 'Valdis',
#   'last_name': 'Teliga',
#   'email': 'vteliga48@jalbum.net',
#   'gender': 'Male',
#   'ip_address': '222.155.151.62'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fcb'),
#   'id': 154,
#   'first_name': 'Valdis',
#   'last_name': 'Boaler',
#   'email': 'vboaler49@va.gov',
#   'gender': 'Male',
#   'ip_address': '39.99.183.30'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fcc'),
#   'id': 155,
#   'first_name': 'Valdis',
#   'last_name': 'Burth',
#   'email': 'vburth4a@theatlantic.com',
#   'gender': 'Male',
#   'ip_address': '60.186.174.29'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fcd'),
#   'id': 156,
#   'first_name': 'Valdis',
#   'last_name': 'Sexcey',
#   'email': 'vsexcey4b@bing.com',
#   'gender': 'Female',
#   'ip_address': '76.156.37.249'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fce'),
#   'id': 157,
#   'first_name': 'Valdis',
#   'last_name': 'Bunkle',
#   'email': 'vbunkle4c@army.mil',
#   'gender': 'Female',
#   'ip_address': '173.225.74.98'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fcf'),
#   'id': 158,
#   'first_name': 'Valdis',
#   'last_name': 'Ettritch',
#   'email': 'vettritch4d@adobe.com',
#   'gender': 'Female',
#   'ip_address': '98.226.146.233'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd0'),
#   'id': 159,
#   'first_name': 'Valdis',
#   'last_name': 'Izac',
#   'email': 'vizac4e@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '112.182.120.174'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd1'),
#   'id': 160,
#   'first_name': 'Valdis',
#   'last_name': 'Lacrouts',
#   'email': 'vlacrouts4f@nba.com',
#   'gender': 'Male',
#   'ip_address': '47.129.59.112'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd2'),
#   'id': 161,
#   'first_name': 'Valdis',
#   'last_name': 'Leynagh',
#   'email': 'vleynagh4g@parallels.com',
#   'gender': 'Female',
#   'ip_address': '2.163.238.55'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd3'),
#   'id': 162,
#   'first_name': 'Valdis',
#   'last_name': 'Blanchette',
#   'email': 'vblanchette4h@ucoz.com',
#   'gender': 'Male',
#   'ip_address': '124.90.234.47'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd4'),
#   'id': 163,
#   'first_name': 'Valdis',
#   'last_name': 'Teasdale',
#   'email': 'vteasdale4i@odnoklassniki.ru',
#   'gender': 'Male',
#   'ip_address': '60.179.136.144'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd5'),
#   'id': 164,
#   'first_name': 'Valdis',
#   'last_name': "O'Mullaney",
#   'email': 'vomullaney4j@barnesandnoble.com',
#   'gender': 'Male',
#   'ip_address': '5.40.36.181'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd6'),
#   'id': 165,
#   'first_name': 'Valdis',
#   'last_name': 'Coggles',
#   'email': 'vcoggles4k@goo.gl',
#   'gender': 'Male',
#   'ip_address': '185.111.139.136'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd7'),
#   'id': 166,
#   'first_name': 'Valdis',
#   'last_name': 'Tantrum',
#   'email': 'vtantrum4l@addthis.com',
#   'gender': 'Female',
#   'ip_address': '233.251.101.231'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd8'),
#   'id': 167,
#   'first_name': 'Valdis',
#   'last_name': 'Blood',
#   'email': 'vblood4m@livejournal.com',
#   'gender': 'Female',
#   'ip_address': '37.44.195.245'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd9'),
#   'id': 168,
#   'first_name': 'Valdis',
#   'last_name': 'Cochran',
#   'email': 'vcochran4n@yahoo.co.jp',
#   'gender': 'Male',
#   'ip_address': '139.136.118.14'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fda'),
#   'id': 169,
#   'first_name': 'Valdis',
#   'last_name': 'Pass',
#   'email': 'vpass4o@miitbeian.gov.cn',
#   'gender': 'Male',
#   'ip_address': '234.107.154.96'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fdb'),
#   'id': 170,
#   'first_name': 'Valdis',
#   'last_name': 'Sutcliff',
#   'email': 'vsutcliff4p@uiuc.edu',
#   'gender': 'Female',
#   'ip_address': '145.103.51.96'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fdc'),
#   'id': 171,
#   'first_name': 'Valdis',
#   'last_name': 'Ashley',
#   'email': 'vashley4q@ustream.tv',
#   'gender': 'Male',
#   'ip_address': '70.130.226.134'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fdd'),
#   'id': 172,
#   'first_name': 'Valdis',
#   'last_name': 'Cuzen',
#   'email': 'vcuzen4r@flavors.me',
#   'gender': 'Female',
#   'ip_address': '155.51.82.56'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fde'),
#   'id': 173,
#   'first_name': 'Valdis',
#   'last_name': 'Darracott',
#   'email': 'vdarracott4s@indiatimes.com',
#   'gender': 'Male',
#   'ip_address': '231.136.199.90'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fdf'),
#   'id': 174,
#   'first_name': 'Valdis',
#   'last_name': 'Roderighi',
#   'email': 'vroderighi4t@163.com',
#   'gender': 'Female',
#   'ip_address': '128.110.145.79'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe0'),
#   'id': 175,
#   'first_name': 'Valdis',
#   'last_name': 'Bricknell',
#   'email': 'vbricknell4u@vinaora.com',
#   'gender': 'Female',
#   'ip_address': '227.122.204.251'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe1'),
#   'id': 176,
#   'first_name': 'Valdis',
#   'last_name': 'Darton',
#   'email': 'vdarton4v@si.edu',
#   'gender': 'Female',
#   'ip_address': '237.151.254.143'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe2'),
#   'id': 177,
#   'first_name': 'Valdis',
#   'last_name': 'Waby',
#   'email': 'vwaby4w@tripadvisor.com',
#   'gender': 'Male',
#   'ip_address': '129.53.213.252'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe3'),
#   'id': 178,
#   'first_name': 'Valdis',
#   'last_name': 'Keeting',
#   'email': 'vkeeting4x@columbia.edu',
#   'gender': 'Female',
#   'ip_address': '99.69.200.136'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe4'),
#   'id': 179,
#   'first_name': 'Valdis',
#   'last_name': 'Danilov',
#   'email': 'vdanilov4y@umich.edu',
#   'gender': 'Male',
#   'ip_address': '85.165.69.232'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe5'),
#   'id': 180,
#   'first_name': 'Valdis',
#   'last_name': 'Bevens',
#   'email': 'vbevens4z@forbes.com',
#   'gender': 'Male',
#   'ip_address': '118.27.3.184'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe6'),
#   'id': 181,
#   'first_name': 'Valdis',
#   'last_name': 'Struys',
#   'email': 'vstruys50@hp.com',
#   'gender': 'Male',
#   'ip_address': '135.59.63.40'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe7'),
#   'id': 182,
#   'first_name': 'Valdis',
#   'last_name': 'Attle',
#   'email': 'vattle51@g.co',
#   'gender': 'Male',
#   'ip_address': '146.32.75.7'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe8'),
#   'id': 183,
#   'first_name': 'Valdis',
#   'last_name': 'Isard',
#   'email': 'visard52@merriam-webster.com',
#   'gender': 'Female',
#   'ip_address': '215.54.210.61'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe9'),
#   'id': 184,
#   'first_name': 'Valdis',
#   'last_name': 'Adamson',
#   'email': 'vadamson53@jugem.jp',
#   'gender': 'Male',
#   'ip_address': '72.41.62.49'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fea'),
#   'id': 185,
#   'first_name': 'Valdis',
#   'last_name': 'Stelljes',
#   'email': 'vstelljes54@tuttocitta.it',
#   'gender': 'Female',
#   'ip_address': '244.4.96.253'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3feb'),
#   'id': 186,
#   'first_name': 'Valdis',
#   'last_name': 'Liven',
#   'email': 'vliven55@ifeng.com',
#   'gender': 'Female',
#   'ip_address': '224.25.191.3'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fec'),
#   'id': 187,
#   'first_name': 'Valdis',
#   'last_name': 'Snellman',
#   'email': 'vsnellman56@amazon.co.jp',
#   'gender': 'Female',
#   'ip_address': '76.193.130.37'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fed'),
#   'id': 188,
#   'first_name': 'Valdis',
#   'last_name': 'Stripp',
#   'email': 'vstripp57@smh.com.au',
#   'gender': 'Male',
#   'ip_address': '242.135.95.224'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fee'),
#   'id': 189,
#   'first_name': 'Valdis',
#   'last_name': 'Ellison',
#   'email': 'vellison58@theguardian.com',
#   'gender': 'Male',
#   'ip_address': '250.58.74.49'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fef'),
#   'id': 190,
#   'first_name': 'Valdis',
#   'last_name': 'Cran',
#   'email': 'vcran59@lulu.com',
#   'gender': 'Female',
#   'ip_address': '85.6.208.203'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff0'),
#   'id': 191,
#   'first_name': 'Valdis',
#   'last_name': 'Digance',
#   'email': 'vdigance5a@ocn.ne.jp',
#   'gender': 'Female',
#   'ip_address': '47.164.60.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff1'),
#   'id': 192,
#   'first_name': 'Valdis',
#   'last_name': 'Yoxall',
#   'email': 'vyoxall5b@skype.com',
#   'gender': 'Male',
#   'ip_address': '186.180.178.125'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff2'),
#   'id': 193,
#   'first_name': 'Valdis',
#   'last_name': 'MacGibbon',
#   'email': 'vmacgibbon5c@loc.gov',
#   'gender': 'Female',
#   'ip_address': '15.15.111.224'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff3'),
#   'id': 194,
#   'first_name': 'Valdis',
#   'last_name': 'Leal',
#   'email': 'vleal5d@wp.com',
#   'gender': 'Male',
#   'ip_address': '53.2.21.190'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff4'),
#   'id': 195,
#   'first_name': 'Valdis',
#   'last_name': 'Knudsen',
#   'email': 'vknudsen5e@accuweather.com',
#   'gender': 'Female',
#   'ip_address': '206.78.0.107'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff5'),
#   'id': 196,
#   'first_name': 'Valdis',
#   'last_name': 'Elphinston',
#   'email': 'velphinston5f@shinystat.com',
#   'gender': 'Female',
#   'ip_address': '65.76.113.84'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff6'),
#   'id': 197,
#   'first_name': 'Valdis',
#   'last_name': 'Pope',
#   'email': 'vpope5g@ed.gov',
#   'gender': 'Female',
#   'ip_address': '48.184.197.179'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff7'),
#   'id': 198,
#   'first_name': 'Valdis',
#   'last_name': 'Behrens',
#   'email': 'vbehrens5h@1688.com',
#   'gender': 'Male',
#   'ip_address': '90.54.136.81'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff8'),
#   'id': 199,
#   'first_name': 'Valdis',
#   'last_name': 'Staves',
#   'email': 'vstaves5i@who.int',
#   'gender': 'Female',
#   'ip_address': '203.88.222.214'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff9'),
#   'id': 200,
#   'first_name': 'Valdis',
#   'last_name': 'Noddle',
#   'email': 'vnoddle5j@buzzfeed.com',
#   'gender': 'Male',
#   'ip_address': '190.55.249.92'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffa'),
#   'id': 201,
#   'first_name': 'Valdis',
#   'last_name': 'Cawkill',
#   'email': 'vcawkill5k@yahoo.co.jp',
#   'gender': 'Female',
#   'ip_address': '252.220.196.160'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffb'),
#   'id': 202,
#   'first_name': 'Valdis',
#   'last_name': 'Bayliss',
#   'email': 'vbayliss5l@tinypic.com',
#   'gender': 'Female',
#   'ip_address': '255.211.164.214'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffc'),
#   'id': 203,
#   'first_name': 'Valdis',
#   'last_name': 'Merner',
#   'email': 'vmerner5m@shareasale.com',
#   'gender': 'Female',
#   'ip_address': '154.164.158.27'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffd'),
#   'id': 204,
#   'first_name': 'Valdis',
#   'last_name': 'Khidr',
#   'email': 'vkhidr5n@weather.com',
#   'gender': 'Male',
#   'ip_address': '232.75.112.47'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffe'),
#   'id': 205,
#   'first_name': 'Valdis',
#   'last_name': 'Arnaldo',
#   'email': 'varnaldo5o@altervista.org',
#   'gender': 'Male',
#   'ip_address': '168.151.225.23'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fff'),
#   'id': 206,
#   'first_name': 'Valdis',
#   'last_name': 'Torresi',
#   'email': 'vtorresi5p@wikipedia.org',
#   'gender': 'Female',
#   'ip_address': '185.108.13.11'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4000'),
#   'id': 207,
#   'first_name': 'Valdis',
#   'last_name': 'Dils',
#   'email': 'vdils5q@eventbrite.com',
#   'gender': 'Female',
#   'ip_address': '10.139.67.176'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4001'),
#   'id': 208,
#   'first_name': 'Valdis',
#   'last_name': 'Beevors',
#   'email': 'vbeevors5r@dell.com',
#   'gender': 'Female',
#   'ip_address': '166.65.184.199'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4002'),
#   'id': 209,
#   'first_name': 'Valdis',
#   'last_name': 'Dagworthy',
#   'email': 'vdagworthy5s@freewebs.com',
#   'gender': 'Male',
#   'ip_address': '181.171.119.232'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4003'),
#   'id': 210,
#   'first_name': 'Valdis',
#   'last_name': 'Faulks',
#   'email': 'vfaulks5t@columbia.edu',
#   'gender': 'Female',
#   'ip_address': '145.28.6.112'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4004'),
#   'id': 211,
#   'first_name': 'Valdis',
#   'last_name': 'Hush',
#   'email': 'vhush5u@dell.com',
#   'gender': 'Male',
#   'ip_address': '242.7.26.17'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4005'),
#   'id': 212,
#   'first_name': 'Valdis',
#   'last_name': 'Parks',
#   'email': 'vparks5v@mapquest.com',
#   'gender': 'Female',
#   'ip_address': '14.246.68.38'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4006'),
#   'id': 213,
#   'first_name': 'Valdis',
#   'last_name': 'Buie',
#   'email': 'vbuie5w@google.com.au',
#   'gender': 'Male',
#   'ip_address': '88.24.30.220'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4007'),
#   'id': 214,
#   'first_name': 'Valdis',
#   'last_name': 'Beddoe',
#   'email': 'vbeddoe5x@ovh.net',
#   'gender': 'Female',
#   'ip_address': '77.111.167.243'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4008'),
#   'id': 215,
#   'first_name': 'Valdis',
#   'last_name': 'Rubinovitsch',
#   'email': 'vrubinovitsch5y@cbsnews.com',
#   'gender': 'Female',
#   'ip_address': '80.93.73.34'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4009'),
#   'id': 216,
#   'first_name': 'Valdis',
#   'last_name': 'Kose',
#   'email': 'vkose5z@tuttocitta.it',
#   'gender': 'Male',
#   'ip_address': '142.68.213.31'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400a'),
#   'id': 217,
#   'first_name': 'Valdis',
#   'last_name': 'Mimmack',
#   'email': 'vmimmack60@elegantthemes.com',
#   'gender': 'Female',
#   'ip_address': '149.179.100.255'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400b'),
#   'id': 218,
#   'first_name': 'Valdis',
#   'last_name': 'Tortoishell',
#   'email': 'vtortoishell61@4shared.com',
#   'gender': 'Male',
#   'ip_address': '0.10.22.121'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400c'),
#   'id': 219,
#   'first_name': 'Valdis',
#   'last_name': 'Elfe',
#   'email': 'velfe62@nps.gov',
#   'gender': 'Male',
#   'ip_address': '85.13.179.180'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400d'),
#   'id': 220,
#   'first_name': 'Valdis',
#   'last_name': 'Dixcee',
#   'email': 'vdixcee63@harvard.edu',
#   'gender': 'Male',
#   'ip_address': '119.139.250.26'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400e'),
#   'id': 221,
#   'first_name': 'Valdis',
#   'last_name': 'McIlharga',
#   'email': 'vmcilharga64@etsy.com',
#   'gender': 'Female',
#   'ip_address': '33.170.125.30'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e400f'),
#   'id': 222,
#   'first_name': 'Valdis',
#   'last_name': 'Illidge',
#   'email': 'villidge65@mail.ru',
#   'gender': 'Male',
#   'ip_address': '234.19.62.254'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4010'),
#   'id': 223,
#   'first_name': 'Valdis',
#   'last_name': 'Cathee',
#   'email': 'vcathee66@wp.com',
#   'gender': 'Female',
#   'ip_address': '83.239.0.128'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4011'),
#   'id': 224,
#   'first_name': 'Valdis',
#   'last_name': 'Barnhart',
#   'email': 'vbarnhart67@printfriendly.com',
#   'gender': 'Female',
#   'ip_address': '66.49.153.208'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4012'),
#   'id': 225,
#   'first_name': 'Valdis',
#   'last_name': 'Glaum',
#   'email': 'vglaum68@usatoday.com',
#   'gender': 'Female',
#   'ip_address': '245.123.160.73'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4013'),
#   'id': 226,
#   'first_name': 'Valdis',
#   'last_name': 'Cousans',
#   'email': 'vcousans69@ifeng.com',
#   'gender': 'Female',
#   'ip_address': '16.114.163.23'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4014'),
#   'id': 227,
#   'first_name': 'Valdis',
#   'last_name': 'Lowndsborough',
#   'email': 'vlowndsborough6a@youtu.be',
#   'gender': 'Male',
#   'ip_address': '123.65.188.225'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4015'),
#   'id': 228,
#   'first_name': 'Valdis',
#   'last_name': 'Palke',
#   'email': 'vpalke6b@360.cn',
#   'gender': 'Male',
#   'ip_address': '137.63.44.141'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4016'),
#   'id': 229,
#   'first_name': 'Valdis',
#   'last_name': 'Pre',
#   'email': 'vpre6c@moonfruit.com',
#   'gender': 'Male',
#   'ip_address': '173.138.219.139'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4017'),
#   'id': 230,
#   'first_name': 'Valdis',
#   'last_name': 'Dorkin',
#   'email': 'vdorkin6d@bbc.co.uk',
#   'gender': 'Female',
#   'ip_address': '243.140.178.57'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4018'),
#   'id': 231,
#   'first_name': 'Valdis',
#   'last_name': 'Galego',
#   'email': 'vgalego6e@mac.com',
#   'gender': 'Male',
#   'ip_address': '19.249.121.135'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4019'),
#   'id': 232,
#   'first_name': 'Valdis',
#   'last_name': 'Pitcaithley',
#   'email': 'vpitcaithley6f@aboutads.info',
#   'gender': 'Female',
#   'ip_address': '222.109.93.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e401a'),
#   'id': 233,
#   'first_name': 'Valdis',
#   'last_name': 'Bernardon',
#   'email': 'vbernardon6g@scribd.com',
#   'gender': 'Female',
#   'ip_address': '179.36.141.59'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e401b'),
#   'id': 234,
#   'first_name': 'Valdis',
#   'last_name': 'Holborn',
#   'email': 'vholborn6h@etsy.com',
#   'gender': 'Female',
#   'ip_address': '91.219.169.3'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e401c'),
#   'id': 235,
#   'first_name': 'Valdis',
#   'last_name': 'Melburg',
#   'email': 'vmelburg6i@indiatimes.com',
#   'gender': 'Female',
#   'ip_address': '252.114.84.167'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e401d'),
#   'id': 236,
#   'first_name': 'Valdis',
#   'last_name': 'McGirr',
#   'email': 'vmcgirr6j@list-manage.com',
#   'gender': 'Male',
#   'ip_address': '198.248.214.200'},
# ...
#   'last_name': 'De Mattei',
#   'email': 'vdematteibp@dagondesign.com',
#   'gender': 'Female',
#   'ip_address': '38.48.135.237'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40d8'),
#   'id': 423,
#   'first_name': 'Valdis',
#   'last_name': 'Rathjen',
#   'email': 'vrathjenbq@ebay.co.uk',
#   'gender': 'Male',
#   'ip_address': '115.117.233.227'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40d9'),
#   'id': 424,
#   'first_name': 'Valdis',
#   'last_name': 'Heard',
#   'email': 'vheardbr@blogs.com',
#   'gender': 'Female',
#   'ip_address': '134.11.175.255'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40da'),
#   'id': 425,
#   'first_name': 'Valdis',
#   'last_name': 'Inns',
#   'email': 'vinnsbs@about.me',
#   'gender': 'Female',
#   'ip_address': '222.29.173.213'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40db'),
#   'id': 426,
#   'first_name': 'Valdis',
#   'last_name': 'Chivers',
#   'email': 'vchiversbt@google.nl',
#   'gender': 'Male',
#   'ip_address': '66.160.142.222'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40dc'),
#   'id': 427,
#   'first_name': 'Valdis',
#   'last_name': 'Shreve',
#   'email': 'vshrevebu@aboutads.info',
#   'gender': 'Male',
#   'ip_address': '204.16.228.91'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40dd'),
#   'id': 428,
#   'first_name': 'Valdis',
#   'last_name': 'Sperring',
#   'email': 'vsperringbv@wikia.com',
#   'gender': 'Male',
#   'ip_address': '214.123.252.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40de'),
#   'id': 429,
#   'first_name': 'Valdis',
#   'last_name': 'Dreger',
#   'email': 'vdregerbw@economist.com',
#   'gender': 'Female',
#   'ip_address': '142.218.109.226'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40df'),
#   'id': 430,
#   'first_name': 'Valdis',
#   'last_name': 'Ewestace',
#   'email': 'vewestacebx@a8.net',
#   'gender': 'Female',
#   'ip_address': '189.59.172.210'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e0'),
#   'id': 431,
#   'first_name': 'Valdis',
#   'last_name': 'Franzonello',
#   'email': 'vfranzonelloby@wiley.com',
#   'gender': 'Male',
#   'ip_address': '61.245.133.81'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e1'),
#   'id': 432,
#   'first_name': 'Valdis',
#   'last_name': 'McEntagart',
#   'email': 'vmcentagartbz@google.es',
#   'gender': 'Female',
#   'ip_address': '43.34.192.19'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e2'),
#   'id': 433,
#   'first_name': 'Valdis',
#   'last_name': 'Locket',
#   'email': 'vlocketc0@dedecms.com',
#   'gender': 'Female',
#   'ip_address': '2.0.245.210'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e3'),
#   'id': 434,
#   'first_name': 'Valdis',
#   'last_name': 'Backhurst',
#   'email': 'vbackhurstc1@cisco.com',
#   'gender': 'Male',
#   'ip_address': '34.167.64.161'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e4'),
#   'id': 435,
#   'first_name': 'Valdis',
#   'last_name': 'Cazalet',
#   'email': 'vcazaletc2@msu.edu',
#   'gender': 'Male',
#   'ip_address': '55.189.62.169'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e5'),
#   'id': 436,
#   'first_name': 'Valdis',
#   'last_name': 'Strahan',
#   'email': 'vstrahanc3@bandcamp.com',
#   'gender': 'Male',
#   'ip_address': '185.119.176.215'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e6'),
#   'id': 437,
#   'first_name': 'Valdis',
#   'last_name': 'Shillito',
#   'email': 'vshillitoc4@google.com.hk',
#   'gender': 'Female',
#   'ip_address': '12.43.208.196'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e7'),
#   'id': 438,
#   'first_name': 'Valdis',
#   'last_name': 'Hockell',
#   'email': 'vhockellc5@lulu.com',
#   'gender': 'Male',
#   'ip_address': '155.190.182.118'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e8'),
#   'id': 439,
#   'first_name': 'Valdis',
#   'last_name': 'Cornau',
#   'email': 'vcornauc6@studiopress.com',
#   'gender': 'Female',
#   'ip_address': '174.187.154.76'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40e9'),
#   'id': 440,
#   'first_name': 'Valdis',
#   'last_name': 'Huglin',
#   'email': 'vhuglinc7@harvard.edu',
#   'gender': 'Female',
#   'ip_address': '216.237.100.180'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ea'),
#   'id': 441,
#   'first_name': 'Valdis',
#   'last_name': 'Greatbatch',
#   'email': 'vgreatbatchc8@de.vu',
#   'gender': 'Female',
#   'ip_address': '247.240.237.25'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40eb'),
#   'id': 442,
#   'first_name': 'Valdis',
#   'last_name': 'Adshad',
#   'email': 'vadshadc9@issuu.com',
#   'gender': 'Female',
#   'ip_address': '178.196.177.27'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ec'),
#   'id': 443,
#   'first_name': 'Valdis',
#   'last_name': 'Hammor',
#   'email': 'vhammorca@state.gov',
#   'gender': 'Female',
#   'ip_address': '193.86.5.91'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ed'),
#   'id': 444,
#   'first_name': 'Valdis',
#   'last_name': 'Spohr',
#   'email': 'vspohrcb@pagesperso-orange.fr',
#   'gender': 'Male',
#   'ip_address': '240.213.96.160'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ee'),
#   'id': 445,
#   'first_name': 'Valdis',
#   'last_name': 'Frugier',
#   'email': 'vfrugiercc@webeden.co.uk',
#   'gender': 'Female',
#   'ip_address': '170.76.54.177'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ef'),
#   'id': 446,
#   'first_name': 'Valdis',
#   'last_name': 'Darth',
#   'email': 'vdarthcd@gov.uk',
#   'gender': 'Female',
#   'ip_address': '28.228.65.160'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f0'),
#   'id': 447,
#   'first_name': 'Valdis',
#   'last_name': 'Oxteby',
#   'email': 'voxtebyce@studiopress.com',
#   'gender': 'Male',
#   'ip_address': '126.5.244.64'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f1'),
#   'id': 448,
#   'first_name': 'Valdis',
#   'last_name': 'Bruffell',
#   'email': 'vbruffellcf@1und1.de',
#   'gender': 'Female',
#   'ip_address': '46.237.34.123'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f2'),
#   'id': 449,
#   'first_name': 'Valdis',
#   'last_name': 'Reggio',
#   'email': 'vreggiocg@cbsnews.com',
#   'gender': 'Female',
#   'ip_address': '186.251.111.182'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f3'),
#   'id': 450,
#   'first_name': 'Valdis',
#   'last_name': 'Shapera',
#   'email': 'vshaperach@sourceforge.net',
#   'gender': 'Female',
#   'ip_address': '232.205.30.242'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f4'),
#   'id': 451,
#   'first_name': 'Valdis',
#   'last_name': 'Ker',
#   'email': 'vkerci@cornell.edu',
#   'gender': 'Female',
#   'ip_address': '36.220.246.116'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f5'),
#   'id': 452,
#   'first_name': 'Valdis',
#   'last_name': 'Tythe',
#   'email': 'vtythecj@dailymail.co.uk',
#   'gender': 'Female',
#   'ip_address': '175.55.178.1'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f6'),
#   'id': 453,
#   'first_name': 'Valdis',
#   'last_name': 'Goeff',
#   'email': 'vgoeffck@opera.com',
#   'gender': 'Male',
#   'ip_address': '27.131.254.145'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f7'),
#   'id': 454,
#   'first_name': 'Valdis',
#   'last_name': 'Bloss',
#   'email': 'vblosscl@ifeng.com',
#   'gender': 'Male',
#   'ip_address': '216.36.146.183'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f8'),
#   'id': 455,
#   'first_name': 'Valdis',
#   'last_name': 'Elesander',
#   'email': 'velesandercm@barnesandnoble.com',
#   'gender': 'Female',
#   'ip_address': '160.130.73.72'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40f9'),
#   'id': 456,
#   'first_name': 'Valdis',
#   'last_name': 'Lund',
#   'email': 'vlundcn@acquirethisname.com',
#   'gender': 'Male',
#   'ip_address': '168.38.33.137'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40fa'),
#   'id': 457,
#   'first_name': 'Valdis',
#   'last_name': 'Semechik',
#   'email': 'vsemechikco@pbs.org',
#   'gender': 'Female',
#   'ip_address': '82.36.143.184'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40fb'),
#   'id': 458,
#   'first_name': 'Valdis',
#   'last_name': 'McAulay',
#   'email': 'vmcaulaycp@github.io',
#   'gender': 'Female',
#   'ip_address': '239.155.9.13'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40fc'),
#   'id': 459,
#   'first_name': 'Valdis',
#   'last_name': 'Free',
#   'email': 'vfreecq@samsung.com',
#   'gender': 'Female',
#   'ip_address': '60.139.61.99'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40fd'),
#   'id': 460,
#   'first_name': 'Valdis',
#   'last_name': 'Dunford',
#   'email': 'vdunfordcr@icio.us',
#   'gender': 'Female',
#   'ip_address': '90.156.135.43'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40fe'),
#   'id': 461,
#   'first_name': 'Valdis',
#   'last_name': 'Sains',
#   'email': 'vsainscs@gov.uk',
#   'gender': 'Female',
#   'ip_address': '88.146.107.191'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ff'),
#   'id': 462,
#   'first_name': 'Valdis',
#   'last_name': 'Mably',
#   'email': 'vmablyct@mtv.com',
#   'gender': 'Male',
#   'ip_address': '204.53.75.93'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4100'),
#   'id': 463,
#   'first_name': 'Valdis',
#   'last_name': 'Botham',
#   'email': 'vbothamcu@berkeley.edu',
#   'gender': 'Male',
#   'ip_address': '144.114.30.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4101'),
#   'id': 464,
#   'first_name': 'Valdis',
#   'last_name': 'Capelow',
#   'email': 'vcapelowcv@taobao.com',
#   'gender': 'Female',
#   'ip_address': '90.248.203.50'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4102'),
#   'id': 465,
#   'first_name': 'Valdis',
#   'last_name': 'Jasiak',
#   'email': 'vjasiakcw@pbs.org',
#   'gender': 'Male',
#   'ip_address': '147.175.251.32'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4103'),
#   'id': 466,
#   'first_name': 'Valdis',
#   'last_name': 'Dibbe',
#   'email': 'vdibbecx@spiegel.de',
#   'gender': 'Male',
#   'ip_address': '211.152.78.207'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4104'),
#   'id': 467,
#   'first_name': 'Valdis',
#   'last_name': 'Fogel',
#   'email': 'vfogelcy@uiuc.edu',
#   'gender': 'Female',
#   'ip_address': '241.221.80.105'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4105'),
#   'id': 468,
#   'first_name': 'Valdis',
#   'last_name': 'Jerrems',
#   'email': 'vjerremscz@abc.net.au',
#   'gender': 'Male',
#   'ip_address': '185.120.121.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4106'),
#   'id': 469,
#   'first_name': 'Valdis',
#   'last_name': 'Pallant',
#   'email': 'vpallantd0@baidu.com',
#   'gender': 'Female',
#   'ip_address': '109.220.32.227'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4107'),
#   'id': 470,
#   'first_name': 'Valdis',
#   'last_name': 'Condon',
#   'email': 'vcondond1@hhs.gov',
#   'gender': 'Male',
#   'ip_address': '119.92.93.219'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4108'),
#   'id': 471,
#   'first_name': 'Valdis',
#   'last_name': 'Blenkiron',
#   'email': 'vblenkirond2@wired.com',
#   'gender': 'Female',
#   'ip_address': '158.138.28.70'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4109'),
#   'id': 472,
#   'first_name': 'Valdis',
#   'last_name': 'Cottage',
#   'email': 'vcottaged3@gravatar.com',
#   'gender': 'Female',
#   'ip_address': '118.178.130.124'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410a'),
#   'id': 473,
#   'first_name': 'Valdis',
#   'last_name': 'Umpleby',
#   'email': 'vumplebyd4@privacy.gov.au',
#   'gender': 'Female',
#   'ip_address': '125.88.14.71'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410b'),
#   'id': 474,
#   'first_name': 'Valdis',
#   'last_name': 'Yepiskopov',
#   'email': 'vyepiskopovd5@ucla.edu',
#   'gender': 'Male',
#   'ip_address': '95.249.168.59'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410c'),
#   'id': 475,
#   'first_name': 'Valdis',
#   'last_name': 'Sifleet',
#   'email': 'vsifleetd6@goo.gl',
#   'gender': 'Male',
#   'ip_address': '53.47.248.8'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410d'),
#   'id': 476,
#   'first_name': 'Valdis',
#   'last_name': 'Norgate',
#   'email': 'vnorgated7@list-manage.com',
#   'gender': 'Male',
#   'ip_address': '221.176.139.64'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410e'),
#   'id': 477,
#   'first_name': 'Valdis',
#   'last_name': 'Cheves',
#   'email': 'vchevesd8@blog.com',
#   'gender': 'Female',
#   'ip_address': '150.171.165.251'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e410f'),
#   'id': 478,
#   'first_name': 'Valdis',
#   'last_name': 'McCrory',
#   'email': 'vmccroryd9@ed.gov',
#   'gender': 'Male',
#   'ip_address': '143.183.83.15'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4110'),
#   'id': 479,
#   'first_name': 'Valdis',
#   'last_name': 'Desporte',
#   'email': 'vdesporteda@home.pl',
#   'gender': 'Male',
#   'ip_address': '58.56.227.235'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4111'),
#   'id': 480,
#   'first_name': 'Valdis',
#   'last_name': 'Currum',
#   'email': 'vcurrumdb@drupal.org',
#   'gender': 'Female',
#   'ip_address': '155.139.230.32'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4112'),
#   'id': 481,
#   'first_name': 'Valdis',
#   'last_name': 'Stearnes',
#   'email': 'vstearnesdc@vinaora.com',
#   'gender': 'Male',
#   'ip_address': '95.203.90.245'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4113'),
#   'id': 482,
#   'first_name': 'Valdis',
#   'last_name': 'Pardon',
#   'email': 'vpardondd@nymag.com',
#   'gender': 'Male',
#   'ip_address': '133.136.78.153'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4114'),
#   'id': 483,
#   'first_name': 'Valdis',
#   'last_name': 'Kneale',
#   'email': 'vknealede@army.mil',
#   'gender': 'Female',
#   'ip_address': '107.196.237.156'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4115'),
#   'id': 484,
#   'first_name': 'Valdis',
#   'last_name': 'McKimm',
#   'email': 'vmckimmdf@desdev.cn',
#   'gender': 'Female',
#   'ip_address': '195.208.38.53'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4116'),
#   'id': 485,
#   'first_name': 'Valdis',
#   'last_name': 'Strapp',
#   'email': 'vstrappdg@earthlink.net',
#   'gender': 'Male',
#   'ip_address': '110.65.141.61'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4117'),
#   'id': 486,
#   'first_name': 'Valdis',
#   'last_name': 'Wood',
#   'email': 'vwooddh@goo.gl',
#   'gender': 'Female',
#   'ip_address': '132.76.158.161'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4118'),
#   'id': 487,
#   'first_name': 'Valdis',
#   'last_name': 'Dummett',
#   'email': 'vdummettdi@pen.io',
#   'gender': 'Male',
#   'ip_address': '121.166.119.192'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4119'),
#   'id': 488,
#   'first_name': 'Valdis',
#   'last_name': 'Vannacci',
#   'email': 'vvannaccidj@spotify.com',
#   'gender': 'Female',
#   'ip_address': '230.121.175.111'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411a'),
#   'id': 489,
#   'first_name': 'Valdis',
#   'last_name': 'Farady',
#   'email': 'vfaradydk@opera.com',
#   'gender': 'Female',
#   'ip_address': '217.56.168.134'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411b'),
#   'id': 490,
#   'first_name': 'Valdis',
#   'last_name': 'Jacklings',
#   'email': 'vjacklingsdl@bloglovin.com',
#   'gender': 'Male',
#   'ip_address': '127.128.185.75'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411c'),
#   'id': 491,
#   'first_name': 'Valdis',
#   'last_name': 'Overstall',
#   'email': 'voverstalldm@stumbleupon.com',
#   'gender': 'Female',
#   'ip_address': '22.214.80.97'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411d'),
#   'id': 492,
#   'first_name': 'Valdis',
#   'last_name': 'McMichael',
#   'email': 'vmcmichaeldn@aboutads.info',
#   'gender': 'Male',
#   'ip_address': '82.250.20.149'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411e'),
#   'id': 493,
#   'first_name': 'Valdis',
#   'last_name': 'Harlowe',
#   'email': 'vharlowedo@theglobeandmail.com',
#   'gender': 'Female',
#   'ip_address': '21.34.18.31'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e411f'),
#   'id': 494,
#   'first_name': 'Valdis',
#   'last_name': 'Wilmington',
#   'email': 'vwilmingtondp@123-reg.co.uk',
#   'gender': 'Male',
#   'ip_address': '19.244.175.34'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4120'),
#   'id': 495,
#   'first_name': 'Valdis',
#   'last_name': 'Dare',
#   'email': 'vdaredq@auda.org.au',
#   'gender': 'Female',
#   'ip_address': '216.220.64.181'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4121'),
#   'id': 496,
#   'first_name': 'Valdis',
#   'last_name': 'Craigg',
#   'email': 'vcraiggdr@google.de',
#   'gender': 'Female',
#   'ip_address': '51.96.227.131'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4122'),
#   'id': 497,
#   'first_name': 'Valdis',
#   'last_name': 'Lafoy',
#   'email': 'vlafoyds@ycombinator.com',
#   'gender': 'Female',
#   'ip_address': '20.113.179.139'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4123'),
#   'id': 498,
#   'first_name': 'Valdis',
#   'last_name': 'Bourget',
#   'email': 'vbourgetdt@surveymonkey.com',
#   'gender': 'Female',
#   'ip_address': '221.40.241.252'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4124'),
#   'id': 499,
#   'first_name': 'Valdis',
#   'last_name': 'Klimko',
#   'email': 'vklimkodu@google.cn',
#   'gender': 'Female',
#   'ip_address': '23.248.38.135'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4125'),
#   'id': 500,
#   'first_name': 'Valdis',
#   'last_name': "O'Grada",
#   'email': 'vogradadv@technorati.com',
#   'gender': 'Male',
#   'ip_address': '169.75.227.28'}]

# %%
users = list(bigcol.find({"email":{ "$exists": True }}))
len(users)
# Out:
# 500

# %%
# regex matches all characters and then ends with .com 
# . means any character and \. means the dot
jpusers = list(bigcol.find({"email": { "$regex" : ".*\.jp"} }))
len(jpusers)
# Out:
# 25

# %%
jpusers
# Out:
# [{'_id': ObjectId('5ec7e9d8a8571231401e3f34'),
#   'id': 3,
#   'first_name': 'Valdis',
#   'last_name': 'Kopp',
#   'email': 'vkopp2@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '170.70.15.82'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f3d'),
#   'id': 12,
#   'first_name': 'Valdis',
#   'last_name': 'Tomala',
#   'email': 'vtomalab@infoseek.co.jp',
#   'gender': 'Female',
#   'ip_address': '218.184.112.115'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f52'),
#   'id': 33,
#   'first_name': 'Valdis',
#   'last_name': 'Whetland',
#   'email': 'vwhetlandw@dion.ne.jp',
#   'gender': 'Female',
#   'ip_address': '199.0.4.210'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5d'),
#   'id': 44,
#   'first_name': 'Valdis',
#   'last_name': 'Hammant',
#   'email': 'vhammant17@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '172.11.133.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f5e'),
#   'id': 45,
#   'first_name': 'Valdis',
#   'last_name': 'Brayson',
#   'email': 'vbrayson18@plala.or.jp',
#   'gender': 'Male',
#   'ip_address': '201.146.44.136'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f6d'),
#   'id': 60,
#   'first_name': 'Valdis',
#   'last_name': 'Lagne',
#   'email': 'vlagne1n@exblog.jp',
#   'gender': 'Male',
#   'ip_address': '203.128.64.186'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f76'),
#   'id': 69,
#   'first_name': 'Valdis',
#   'last_name': 'Oglevie',
#   'email': 'voglevie1w@jugem.jp',
#   'gender': 'Male',
#   'ip_address': '131.201.106.103'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3f7d'),
#   'id': 76,
#   'first_name': 'Valdis',
#   'last_name': 'Carville',
#   'email': 'vcarville23@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '49.228.112.23'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fbb'),
#   'id': 138,
#   'first_name': 'Valdis',
#   'last_name': 'Gow',
#   'email': 'vgow3t@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '166.216.99.125'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fc8'),
#   'id': 151,
#   'first_name': 'Valdis',
#   'last_name': 'Titley',
#   'email': 'vtitley46@i2i.jp',
#   'gender': 'Female',
#   'ip_address': '125.71.219.186'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd0'),
#   'id': 159,
#   'first_name': 'Valdis',
#   'last_name': 'Izac',
#   'email': 'vizac4e@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '112.182.120.174'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fd9'),
#   'id': 168,
#   'first_name': 'Valdis',
#   'last_name': 'Cochran',
#   'email': 'vcochran4n@yahoo.co.jp',
#   'gender': 'Male',
#   'ip_address': '139.136.118.14'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fe9'),
#   'id': 184,
#   'first_name': 'Valdis',
#   'last_name': 'Adamson',
#   'email': 'vadamson53@jugem.jp',
#   'gender': 'Male',
#   'ip_address': '72.41.62.49'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3fec'),
#   'id': 187,
#   'first_name': 'Valdis',
#   'last_name': 'Snellman',
#   'email': 'vsnellman56@amazon.co.jp',
#   'gender': 'Female',
#   'ip_address': '76.193.130.37'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ff0'),
#   'id': 191,
#   'first_name': 'Valdis',
#   'last_name': 'Digance',
#   'email': 'vdigance5a@ocn.ne.jp',
#   'gender': 'Female',
#   'ip_address': '47.164.60.133'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e3ffa'),
#   'id': 201,
#   'first_name': 'Valdis',
#   'last_name': 'Cawkill',
#   'email': 'vcawkill5k@yahoo.co.jp',
#   'gender': 'Female',
#   'ip_address': '252.220.196.160'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4032'),
#   'id': 257,
#   'first_name': 'Valdis',
#   'last_name': 'Kinnen',
#   'email': 'vkinnen74@japanpost.jp',
#   'gender': 'Male',
#   'ip_address': '6.166.105.17'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e406d'),
#   'id': 316,
#   'first_name': 'Valdis',
#   'last_name': 'Mollin',
#   'email': 'vmollin8r@infoseek.co.jp',
#   'gender': 'Female',
#   'ip_address': '55.138.249.164'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e406f'),
#   'id': 318,
#   'first_name': 'Valdis',
#   'last_name': 'Robroe',
#   'email': 'vrobroe8t@dion.ne.jp',
#   'gender': 'Female',
#   'ip_address': '92.175.14.179'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e4077'),
#   'id': 326,
#   'first_name': 'Valdis',
#   'last_name': 'Healeas',
#   'email': 'vhealeas91@google.co.jp',
#   'gender': 'Female',
#   'ip_address': '88.228.77.4'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e407b'),
#   'id': 330,
#   'first_name': 'Valdis',
#   'last_name': 'Relf',
#   'email': 'vrelf95@ameblo.jp',
#   'gender': 'Male',
#   'ip_address': '3.251.219.53'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e408a'),
#   'id': 345,
#   'first_name': 'Valdis',
#   'last_name': 'Vakhlov',
#   'email': 'vvakhlov9k@ocn.ne.jp',
#   'gender': 'Female',
#   'ip_address': '136.58.218.76'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40ac'),
#   'id': 379,
#   'first_name': 'Valdis',
#   'last_name': 'Killerby',
#   'email': 'vkillerbyai@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '93.36.231.204'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40be'),
#   'id': 397,
#   'first_name': 'Valdis',
#   'last_name': 'MacDonagh',
#   'email': 'vmacdonaghb0@plala.or.jp',
#   'gender': 'Female',
#   'ip_address': '146.17.224.80'},
#  {'_id': ObjectId('5ec7e9d8a8571231401e40d1'),
#   'id': 416,
#   'first_name': 'Valdis',
#   'last_name': 'Warbey',
#   'email': 'vwarbeybj@amazon.co.jp',
#   'gender': 'Female',
#   'ip_address': '142.224.66.240'}]

# %%
".com" in "lspray8@homestead.com"
# Out:
# True

# %%
email = "lspray8@homestead.com"
email.endswith(".com")
# Out:
# True

# %%
comusers = []
for user in users:
    if user['email'].endswith(".com"):
        comusers.append(user)
len(comusers)
# Out:
# 30

# %%
comusers = [user for user in users if user['email'].endswith(".com")]
len(comusers)
# Out:
# 30

# %%
women = list(mock.find({"gender":"Female", "email": { "$regex" : ".*\.com"}}))
len(women)
# Out:
# 13

# %%
# find all women with non .com emails
# 1. Find All women using MongoDP
# 2. Filter using Python to get non commercial emails
women = list(mock.find({"gender":"Female"}))
len(women)
# Out:
# 16

# %%
noncom = [user for user in women if not user['email'].endswith(".com")]
noncom
# Out:
# [{'_id': ObjectId('5e5a55dd1571784c5d49250b'),
#   'id': 3,
#   'first_name': 'Ilze',
#   'last_name': 'Sylvaine',
#   'email': 'isylvaine2@uiuc.edu',
#   'gender': 'Female',
#   'ip_address': '124.141.79.153'},
#  {'_id': ObjectId('5e5a567ec529bae9183013e4'),
#   'id': 7,
#   'first_name': 'Inese',
#   'last_name': 'Pavolini',
#   'email': 'ipavolini6@mail.ru',
#   'gender': 'Female',
#   'ip_address': '147.67.91.39'},
#  {'_id': ObjectId('5e5a567ec529bae9183013e6'),
#   'id': 9,
#   'first_name': 'Inese',
#   'last_name': 'Coneybeare',
#   'email': 'iconeybeare8@vkontakte.ru',
#   'gender': 'Female',
#   'ip_address': '74.154.140.162'}]
